# %% [markdown]
# ### Generate Embeddings to JSON Files

# %%
import os

from dotenv import load_dotenv
from openai import AzureOpenAI

# %%
load_dotenv(override=True)

client = AzureOpenAI(
    api_key=os.getenv("AZURE_OPENAI_EMBEDDING_API_KEY"),
    api_version=os.getenv("AZURE_OPENAI_EMBEDDING_VERSION"),
    azure_endpoint=os.getenv("AZURE_OPENAI_EMBEDDING_ENDPOINT"),
)

# %%
response = client.embeddings.create(
    input="Hello world",
    model=os.getenv("AZURE_OPENAI_EMBEDDING_DEPLOYMENT_NAME"),
)

print(len(response.data[0].embedding))
print(response.data[0].embedding)
# Out:
# 1536
# [-0.002078542485833168, -0.04908587411046028, 0.020946789532899857, 0.03135102614760399, -0.04530530795454979, -0.026402482762932777, -0.028999701142311096, 0.06030462309718132, -0.02571091614663601, -0.01482258178293705, 0.015444992110133171, -0.029983261600136757, -0.020393535494804382, -0.03334888815879822, 0.025833861902356148, 0.014207855798304081, -0.0700787678360939, 0.012432834133505821, 0.014791845344007015, 0.048839982599020004, 0.02073163539171219, -0.008890475146472454, -0.015114576555788517, -0.01661297120153904, 0.025926070287823677, -0.002902659587562084, -0.024327782914042473, 0.024281678721308708, 0.0017433245666325092, -0.055724915117025375, 0.02308296225965023, -0.045489728450775146, -0.008652268908917904, 0.0031619970686733723, 0.004583551082760096, 0.001794231589883566, 0.02669447846710682, 0.010158347897231579, -0.012056314386427402, -0.011472324840724468, -0.01491479016840458, -0.023129066452383995, 0.025357449427247047, 0.036822088062763214, -0.035500429570674896, 0.02126952074468136, -0.06307089328765869, 0.04038750007748604, 0.05354263633489609, 0.06153407692909241, -0.033656250685453415, -0.0066582513973116875, 0.02549576200544834, 0.10966712236404419, -0.004683443810790777, -0.03946541249752045, 0.007119296118617058, 0.05151404067873955, -0.026325643062591553, 0.027877826243638992, 0.030428938567638397, 0.020593322813510895, 0.01724306493997574, 0.012355993501842022, 0.0010844151256605983, 0.007092401850968599, -0.03706797957420349, 0.02352863922715187, -0.010665496811270714, 0.04084854573011398, -0.002132331021130085, 0.03136639669537544, -0.042723458260297775, -0.006758144591003656, -0.0472416952252388, -0.021807406097650528, -0.045674145221710205, 0.000996048329398036, 8.950746996561065e-05, -0.04745684936642647, -0.03294931724667549, 0.023421062156558037, -0.05286644026637077, -0.05621669441461563, -0.022560445591807365, 0.01804220862686634, -0.03590000048279762, 0.0011708609526976943, -0.006001262925565243, -0.019840283319354057, 0.011226434260606766, 0.0009922062745317817, -0.02010154165327549, 0.04512089118361473, 0.04137106239795685, 0.005490271840244532, -0.007296029478311539, 0.03915804997086525, 0.059720635414123535, -0.008675321005284786, 0.027908561751246452, -0.02403578720986843, 0.026264170184731483, -0.016028981655836105, 0.008867423050105572, 0.011725898832082748, -0.00017241144087165594, -0.04613519087433815, -0.025065453723073006, 0.004598919302225113, -0.11231044679880142, -0.015368150547146797, 0.013416395522654057, -0.03119734674692154, 0.00516754062846303, 0.03307225927710533, 0.08145119994878769, -0.05741541087627411, 0.017319906502962112, -0.06798870116472244, 0.020854581147432327, 0.0027163205668330193, -0.01771947741508484, -0.05855265632271767, -0.057937927544116974, -0.026341009885072708, -0.010511815547943115, 0.03749828785657883, -0.041647687554359436, 0.007199978921562433, 0.028999701142311096, 0.026771318167448044, 0.016397817060351372, -0.006566042546182871, -0.04711874946951866, 0.012717144563794136, -0.035654108971357346, -0.022852441295981407, -0.03442465886473656, 0.039772775024175644, 0.053757790476083755, -0.05102226138114929, 0.0027547411154955626, -0.04201652482151985, -0.0034386238548904657, -0.04201652482151985, -0.002111199777573347, 0.03301078826189041, -0.02317517250776291, 0.005620901007205248, 0.04386070370674133, 0.05858338996767998, -0.0580301396548748, 0.015275942161679268, 0.029399272054433823, -0.007226873189210892, 0.03534674644470215, -0.03503938391804695, -0.01109580509364605, 0.00738055445253849, 0.019871018826961517, 0.03190428018569946, -0.036576200276613235, -0.016151927411556244, -0.011426220647990704, 0.0034674389753490686, -0.0019296634709462523, 0.004141716752201319, -0.047733478248119354, 0.007107769604772329, 0.017289169132709503, 0.014154067263007164, -0.02305222675204277, -0.05621669441461563, -0.013554709032177925, 0.01499931514263153, 0.01747358776628971, -0.05243613198399544, -0.010680864565074444, -0.040664128959178925, 0.04155 ...

# %%
import json
from ipywidgets import IntProgress
from IPython.display import display

# %%
transformed_dir = "../data/transformed"
embedded_dir = "../data/embedded"

if not os.path.exists(embedded_dir):
    os.makedirs(embedded_dir)

# %%
def prepare_embedding_str(review_json):
    return f"REVIEW_TITLE: {review_json['review_title']} REVIEW_TEXT: {review_json['review_text']} HOTEL_NAME: {review_json['hotel_name']} HOTEL_CITY: {review_json['city']} HOTEL_STATE: {review_json['hotel_state']}"

# %%
files = os.listdir(transformed_dir)
total_files = len(files)

print(f"Total files to process: {total_files}")
# Out:
# Total files to process: 999

# %%
max_count = total_files
progress_bar = IntProgress(min=0, max=max_count, description="Progress:")

display(progress_bar)

for file in os.listdir(transformed_dir):
    with open(f"{transformed_dir}/{file}", "r") as f:
        review = json.load(f)

        # start here
        embedding_str = prepare_embedding_str(review)
        response = client.embeddings.create(
            input=embedding_str,
            model=os.getenv("AZURE_OPENAI_EMBEDDING_DEPLOYMENT_NAME"),
        )

        review['embedding'] = response.data[0].embedding

        with open(f"{embedded_dir}/{file}", "w") as f:
            json.dump(review, f, indent=2)

        print(
            f"Processed file {file} with embedding length {len(review['embedding'])}")

        progress_bar.value += 1
# Out:
# IntProgress(value=0, description='Progress:', max=999)
# Processed file review_1.json with embedding length 1536
# Processed file review_10.json with embedding length 1536
# Processed file review_100.json with embedding length 1536
# Processed file review_101.json with embedding length 1536
# Processed file review_102.json with embedding length 1536
# Processed file review_103.json with embedding length 1536
# Processed file review_104.json with embedding length 1536
# Processed file review_105.json with embedding length 1536
# Processed file review_106.json with embedding length 1536
# Processed file review_107.json with embedding length 1536
# Processed file review_108.json with embedding length 1536
# Processed file review_109.json with embedding length 1536
# Processed file review_11.json with embedding length 1536
# Processed file review_110.json with embedding length 1536
# Processed file review_111.json with embedding length 1536
# Processed file review_112.json with embedding length 1536
# Processed file review_113.json with embedding length 1536
# Processed file review_114.json with embedding length 1536
# Processed file review_115.json with embedding length 1536
# Processed file review_116.json with embedding length 1536
# Processed file review_117.json with embedding length 1536
# Processed file review_118.json with embedding length 1536
# Processed file review_119.json with embedding length 1536
# Processed file review_12.json with embedding length 1536
# Processed file review_120.json with embedding length 1536
# Processed file review_121.json with embedding length 1536
# Processed file review_122.json with embedding length 1536
# Processed file review_123.json with embedding length 1536
# Processed file review_124.json with embedding length 1536
# Processed file review_125.json with embedding length 1536
# Processed file review_126.json with embedding length 1536
# Processed file review_127.json with embedding length 1536
# Processed file review_128.json with embedding length 1536
# Processed file review_129.json with embedding length 1536
# Processed file review_13.json with embedding length 1536
# Processed file review_130.json with embedding length 1536
# Processed file review_131.json with embedding length 1536
# Processed file review_132.json with embedding length 1536
# Processed file review_133.json with embedding length 1536
# Processed file review_134.json with embedding length 1536
# Processed file review_135.json with embedding length 1536
# Processed file review_136.json with embedding length 1536
# Processed file review_137.json with embedding length 1536
# Processed file review_138.json with embedding length 1536
# Processed file review_139.json with embedding length 1536
# Processed file review_14.json with embedding length 1536
# Processed file review_140.json with embedding length 1536
# Processed file review_141.json with embedding length 1536
# Processed file review_142.json with embedding length 1536
# Processed file review_143.json with embedding length 1536
# Processed file review_144.json with embedding length 1536
# Processed file review_145.json with embedding length 1536
# Processed file review_146.json with embedding length 1536
# Processed file review_147.json with embedding length 1536
# Processed file review_148.json with embedding length 1536
# Processed file review_149.json with embedding length 1536
# Processed file review_15.json with embedding length 1536
# Processed file review_150.json with embedding length 1536
# Processed file review_151.json with embedding length 1536
# Processed file review_152.json with embedding length 1536
# Processed file review_153.json with embedding length 1536
# Processed file review_154.json with embedding length 1536
# Processed file review_155.json with embedding length 1536
# Processed file review_156.json with embedding length 1536
# Processed file review_157.json with embedding length 1536
# Processed file review_158.json with embedding length 1536
# Processed file review_159.json with embedding length 1536
# Processed file review_16.json with embedding length 1536
# Processed file review_160.json with embedding length 1536
# Processed file review_161.json with embedding length 1536
# Processed file review_162.json with embedding length 1536
# Processed file review_163.json with embedding length 1536
# Processed file review_164.json with embedding length 1536
# Processed file review_165.json with embedding length 1536
# Processed file review_166.json with embedding length 1536
# Processed file review_167.json with embedding length 1536
# Processed file review_168.json with embedding length 1536
# Processed file review_169.json with embedding length 1536
# Processed file review_17.json with embedding length 1536
# Processed file review_170.json with embedding length 1536
# Processed file review_171.json with embedding length 1536
# Processed file review_172.json with embedding length 1536
# Processed file review_173.json with embedding length 1536
# Processed file review_174.json with embedding length 1536
# Processed file review_175.json with embedding length 1536
# Processed file review_176.json with embedding length 1536
# Processed file review_177.json with embedding length 1536
# Processed file review_178.json with embedding length 1536
# Processed file review_179.json with embedding length 1536
# Processed file review_18.json with embedding length 1536
# Processed file review_180.json with embedding length 1536
# Processed file review_181.json with embedding length 1536
# Processed file review_182.json with embedding length 1536
# Processed file review_183.json with embedding length 1536
# Processed file review_184.json with embedding length 1536
# Processed file review_185.json with embedding length 1536
# Processed file review_186.json with embedding length 1536
# Processed file review_187.json with embedding length 1536
# Processed file review_188.json with embedding length 1536
# Processed file review_189.json with embedding length 1536
# Processed file review_19.json with embedding length 1536
# Processed file review_190.json with embedding length 1536
# Processed file review_191.json with embedding length 1536
# Processed file review_192.json with embedding length 1536
# Processed file review_193.json with embedding length 1536
# Processed file review_194.json with embedding length 1536
# Processed file review_195.json with embedding length 1536
# Processed file review_196.json with embedding length 1536
# Processed file review_197.json with embedding length 1536
# Processed file review_198.json with embedding length 1536
# Processed file review_199.json with embedding length 1536
# Processed file review_2.json with embedding length 1536
# Processed file review_20.json with embedding length 1536
# Processed file review_200.json with embedding length 1536
# Processed file review_201.json with embedding length 1536
# Processed file review_202.json with embedding length 1536
# Processed file review_203.json with embedding length 1536
# Processed file review_204.json with embedding length 1536
# Processed file review_205.json with embedding length 1536
# Processed file review_206.json with embedding length 1536
# Processed file review_207.json with embedding length 1536
# Processed file review_208.json with embedding length 1536
# Processed file review_209.json with embedding length 1536
# Processed file review_21.json with embedding length 1536
# Processed file review_210.json with embedding length 1536
# Processed file review_211.json with embedding length 1536
# Processed file review_212.json with embedding length 1536
# Processed file review_213.json with embedding length 1536
# Processed file review_214.json with embedding length 1536
# Processed file review_215.json with embedding length 1536
# Processed file review_216.json with embedding length 1536
# Processed file review_217.json with embedding length 1536
# Processed file review_218.json with embedding length 1536
# Processed file review_219.json with embedding length 1536
# Processed file review_22.json with embedding length 1536
# Processed file review_220.json with embedding length 1536
# Processed file review_221.json with embedding length 1536
# Processed file review_222.json with embedding length 1536
# Processed file review_223.json with embedding length 1536
# Processed file review_224.json with embedding length 1536
# Processed file review_225.json with embedding length 1536
# Processed file review_226.json with embedding length 1536
# Processed file review_227.json with embedding length 1536
# Processed file review_228.json with embedding length 1536
# Processed file review_229.json with embedding length 1536
# Processed file review_23.json with embedding length 1536
# Processed file review_230.json with embedding length 1536
# Processed file review_231.json with embedding length 1536
# Processed file review_232.json with embedding length 1536
# Processed file review_233.json with embedding length 1536
# Processed file review_234.json with embedding length 1536
# Processed file review_235.json with embedding length 1536
# Processed file review_236.json with embedding length 1536
# Processed file review_237.json with embedding length 1536
# Processed file review_238.json with embedding length 1536
# Processed file review_239.json with embedding length 1536
# Processed file review_24.json with embedding length 1536
# Processed file review_240.json with embedding length 1536
# Processed file review_241.json with embedding length 1536
# Processed file review_242.json with embedding length 1536
# Processed file review_243.json with embedding length 1536
# Processed file review_244.json with embedding length 1536
# Processed file review_245.json with embedding length 1536
# Processed file review_246.json with embedding length 1536
# Processed file review_247.json with embedding length 1536
# Processed file review_248.json with embedding length 1536
# Processed file review_249.json with embedding length 1536
# Processed file review_25.json with embedding length 1536
# Processed file review_250.json with embedding length 1536
# Processed file review_251.json with embedding length 1536
# Processed file review_252.json with embedding length 1536
# Processed file review_253.json with embedding length 1536
# Processed file review_254.json with embedding length 1536
# Processed file review_255.json with embedding length 1536
# Processed file review_256.json with embedding length 1536
# Processed file review_257.json with embedding length 1536
# Processed file review_258.json with embedding length 1536
# Processed file review_259.json with embedding length 1536
# Processed file review_26.json with embedding length 1536
# Processed file review_260.json with embedding length 1536
# Processed file review_261.json with embedding length 1536
# Processed file review_262.json with embedding length 1536
# Processed file review_263.json with embedding length 1536
# Processed file review_264.json with embedding length 1536
# Processed file review_265.json with embedding length 1536
# Processed file review_266.json with embedding length 1536
# Processed file review_267.json with embedding length 1536
# Processed file review_268.json with embedding length 1536
# Processed file review_269.json with embedding length 1536
# Processed file review_27.json with embedding length 1536
# Processed file review_270.json with embedding length 1536
# Processed file review_271.json with embedding length 1536
# Processed file review_272.json with embedding length 1536
# Processed file review_273.json with embedding length 1536
# Processed file review_274.json with embedding length 1536
# Processed file review_275.json with embedding length 1536
# Processed file review_276.json with embedding length 1536
# Processed file review_277.json with embedding length 1536
# Processed file review_278.json with embedding length 1536
# Processed file review_279.json with embedding length 1536
# Processed file review_28.json with embedding length 1536
# Processed file review_280.json with embedding length 1536
# Processed file review_281.json with embedding length 1536
# Processed file review_282.json with embedding length 1536
# Processed file review_283.json with embedding length 1536
# Processed file review_284.json with embedding length 1536
# Processed file review_285.json with embedding length 1536
# Processed file review_286.json with embedding length 1536
# Processed file review_287.json with embedding length 1536
# Processed file review_288.json with embedding length 1536
# Processed file review_289.json with embedding length 1536
# Processed file review_29.json with embedding length 1536
# Processed file review_290.json with embedding length 1536
# Processed file review_291.json with embedding length 1536
# Processed file review_292.json with embedding length 1536
# Processed file review_293.json with embedding length 1536
# Processed file review_294.json with embedding length 1536
# Processed file review_295.json with embedding length 1536
# Processed file review_296.json with embedding length 1536
# Processed file review_297.json with embedding length 1536
# Processed file review_298.json with embedding length 1536
# Processed file review_299.json with embedding length 1536
# Processed file review_3.json with embedding length 1536
# Processed file review_30.json with embedding length 1536
# Processed file review_300.json with embedding length 1536
# Processed file review_301.json with embedding length 1536
# Processed file review_302.json with embedding length 1536
# Processed file review_303.json with embedding length 1536
# Processed file review_304.json with embedding length 1536
# Processed file review_305.json with embedding length 1536
# Processed file review_306.json with embedding length 1536
# Processed file review_307.json with embedding length 1536
# Processed file review_308.json with embedding length 1536
# Processed file review_309.json with embedding length 1536
# Processed file review_31.json with embedding length 1536
# Processed file review_310.json with embedding length 1536
# Processed file review_311.json with embedding length 1536
# Processed file review_312.json with embedding length 1536
# Processed file review_313.json with embedding length 1536
# Processed file review_314.json with embedding length 1536
# Processed file review_315.json with embedding length 1536
# Processed file review_316.json with embedding length 1536
# Processed file review_317.json with embedding length 1536
# Processed file review_318.json with embedding length 1536
# Processed file review_319.json with embedding length 1536
# Processed file review_32.json with embedding length 1536
# Processed file review_320.json with embedding length 1536
# Processed file review_321.json with embedding length 1536
# Processed file review_322.json with embedding length 1536
# Processed file review_323.json with embedding length 1536
# Processed file review_324.json with embedding length 1536
# Processed file review_325.json with embedding length 1536
# Processed file review_326.json with embedding length 1536
# Processed file review_327.json with embedding length 1536
# Processed file review_328.json with embedding length 1536
# Processed file review_329.json with embedding length 1536
# Processed file review_33.json with embedding length 1536
# Processed file review_330.json with embedding length 1536
# Processed file review_331.json with embedding length 1536
# Processed file review_332.json with embedding length 1536
# Processed file review_333.json with embedding length 1536
# Processed file review_334.json with embedding length 1536
# Processed file review_335.json with embedding length 1536
# Processed file review_336.json with embedding length 1536
# Processed file review_337.json with embedding length 1536
# Processed file review_338.json with embedding length 1536
# Processed file review_339.json with embedding length 1536
# Processed file review_34.json with embedding length 1536
# Processed file review_340.json with embedding length 1536
# Processed file review_341.json with embedding length 1536
# Processed file review_342.json with embedding length 1536
# Processed file review_343.json with embedding length 1536
# Processed file review_344.json with embedding length 1536
# Processed file review_345.json with embedding length 1536
# Processed file review_346.json with embedding length 1536
# Processed file review_347.json with embedding length 1536
# Processed file review_348.json with embedding length 1536
# Processed file review_349.json with embedding length 1536
# Processed file review_35.json with embedding length 1536
# Processed file review_350.json with embedding length 1536
# Processed file review_351.json with embedding length 1536
# Processed file review_352.json with embedding length 1536
# Processed file review_353.json with embedding length 1536
# Processed file review_354.json with embedding length 1536
# Processed file review_355.json with embedding length 1536
# Processed file review_356.json with embedding length 1536
# Processed file review_357.json with embedding length 1536
# Processed file review_358.json with embedding length 1536
# Processed file review_359.json with embedding length 1536
# Processed file review_36.json with embedding length 1536
# Processed file review_360.json with embedding length 1536
# Processed file review_361.json with embedding length 1536
# Processed file review_362.json with embedding length 1536
# Processed file review_363.json with embedding length 1536
# Processed file review_364.json with embedding length 1536
# Processed file review_365.json with embedding length 1536
# Processed file review_366.json with embedding length 1536
# Processed file review_367.json with embedding length 1536
# Processed file review_368.json with embedding length 1536
# Processed file review_369.json with embedding length 1536
# Processed file review_37.json with embedding length 1536
# Processed file review_370.json with embedding length 1536
# Processed file review_371.json with embedding length 1536
# Processed file review_372.json with embedding length 1536
# Processed file review_373.json with embedding length 1536
# Processed file review_374.json with embedding length 1536
# Processed file review_375.json with embedding length 1536
# Processed file review_376.json with embedding length 1536
# Processed file review_377.json with embedding length 1536
# Processed file review_378.json with embedding length 1536
# Processed file review_379.json with embedding length 1536
# Processed file review_38.json with embedding length 1536
# Processed file review_380.json with embedding length 1536
# Processed file review_381.json with embedding length 1536
# Processed file review_382.json with embedding length 1536
# Processed file review_383.json with embedding length 1536
# Processed file review_384.json with embedding length 1536
# Processed file review_385.json with embedding length 1536
# Processed file review_386.json with embedding length 1536
# Processed file review_387.json with embedding length 1536
# Processed file review_388.json with embedding length 1536
# Processed file review_389.json with embedding length 1536
# Processed file review_39.json with embedding length 1536
# Processed file review_390.json with embedding length 1536
# Processed file review_391.json with embedding length 1536
# Processed file review_392.json with embedding length 1536
# Processed file review_393.json with embedding length 1536
# Processed file review_394.json with embedding length 1536
# Processed file review_395.json with embedding length 1536
# Processed file review_396.json with embedding length 1536
# Processed file review_397.json with embedding length 1536
# Processed file review_398.json with embedding length 1536
# Processed file review_399.json with embedding length 1536
# Processed file review_4.json with embedding length 1536
# Processed file review_40.json with embedding length 1536
# Processed file review_400.json with embedding length 1536
# Processed file review_401.json with embedding length 1536
# Processed file review_402.json with embedding length 1536
# Processed file review_403.json with embedding length 1536
# Processed file review_404.json with embedding length 1536
# Processed file review_405.json with embedding length 1536
# Processed file review_406.json with embedding length 1536
# Processed file review_407.json with embedding length 1536
# Processed file review_408.json with embedding length 1536
# Processed file review_409.json with embedding length 1536
# Processed file review_41.json with embedding length 1536
# Processed file review_410.json with embedding length 1536
# Processed file review_411.json with embedding length 1536
# Processed file review_412.json with embedding length 1536
# Processed file review_413.json with embedding length 1536
# Processed file review_414.json with embedding length 1536
# Processed file review_415.json with embedding length 1536
# Processed file review_416.json with embedding length 1536
# Processed file review_417.json with embedding length 1536
# Processed file review_418.json with embedding length 1536
# Processed file review_419.json with embedding length 1536
# Processed file review_42.json with embedding length 1536
# Processed file review_420.json with embedding length 1536
# Processed file review_421.json with embedding length 1536
# Processed file review_422.json with embedding length 1536
# Processed file review_423.json with embedding length 1536
# Processed file review_424.json with embedding length 1536
# Processed file review_425.json with embedding length 1536
# Processed file review_426.json with embedding length 1536
# Processed file review_427.json with embedding length 1536
# Processed file review_428.json with embedding length 1536
# Processed file review_429.json with embedding length 1536
# Processed file review_43.json with embedding length 1536
# Processed file review_430.json with embedding length 1536
# Processed file review_431.json with embedding length 1536
# Processed file review_432.json with embedding length 1536
# Processed file review_433.json with embedding length 1536
# Processed file review_434.json with embedding length 1536
# Processed file review_435.json with embedding length 1536
# Processed file review_436.json with embedding length 1536
# Processed file review_437.json with embedding length 1536
# Processed file review_438.json with embedding length 1536
# Processed file review_439.json with embedding length 1536
# Processed file review_44.json with embedding length 1536
# Processed file review_440.json with embedding length 1536
# Processed file review_441.json with embedding length 1536
# Processed file review_442.json with embedding length 1536
# Processed file review_443.json with embedding length 1536
# Processed file review_444.json with embedding length 1536
# Processed file review_445.json with embedding length 1536
# Processed file review_446.json with embedding length 1536
# Processed file review_447.json with embedding length 1536
# Processed file review_448.json with embedding length 1536
# Processed file review_449.json with embedding length 1536
# Processed file review_45.json with embedding length 1536
# Processed file review_450.json with embedding length 1536
# Processed file review_451.json with embedding length 1536
# Processed file review_452.json with embedding length 1536
# Processed file review_453.json with embedding length 1536
# Processed file review_454.json with embedding length 1536
# Processed file review_455.json with embedding length 1536
# Processed file review_456.json with embedding length 1536
# Processed file review_457.json with embedding length 1536
# Processed file review_458.json with embedding length 1536
# Processed file review_459.json with embedding length 1536
# Processed file review_46.json with embedding length 1536
# Processed file review_460.json with embedding length 1536
# Processed file review_461.json with embedding length 1536
# Processed file review_462.json with embedding length 1536
# Processed file review_463.json with embedding length 1536
# Processed file review_464.json with embedding length 1536
# Processed file review_465.json with embedding length 1536
# Processed file review_466.json with embedding length 1536
# Processed file review_467.json with embedding length 1536
# Processed file review_468.json with embedding length 1536
# Processed file review_469.json with embedding length 1536
# Processed file review_47.json with embedding length 1536
# Processed file review_470.json with embedding length 1536
# Processed file review_471.json with embedding length 1536
# Processed file review_472.json with embedding length 1536
# Processed file review_473.json with embedding length 1536
# Processed file review_474.json with embedding length 1536
# Processed file review_475.json with embedding length 1536
# Processed file review_476.json with embedding length 1536
# Processed file review_477.json with embedding length 1536
# Processed file review_478.json with embedding length 1536
# Processed file review_479.json with embedding length 1536
# Processed file review_48.json with embedding length 1536
# Processed file review_480.json with embedding length 1536
# Processed file review_481.json with embedding length 1536
# Processed file review_482.json with embedding length 1536
# Processed file review_483.json with embedding length 1536
# Processed file review_484.json with embedding length 1536
# Processed file review_485.json with embedding length 1536
# Processed file review_486.json with embedding length 1536
# Processed file review_487.json with embedding length 1536
# Processed file review_488.json with embedding length 1536
# Processed file review_489.json with embedding length 1536
# Processed file review_49.json with embedding length 1536
# Processed file review_490.json with embedding length 1536
# Processed file review_491.json with embedding length 1536
# Processed file review_492.json with embedding length 1536
# Processed file review_493.json with embedding length 1536
# Processed file review_494.json with embedding length 1536
# Processed file review_495.json with embedding length 1536
# Processed file review_496.json with embedding length 1536
# Processed file review_497.json with embedding length 1536
# Processed file review_498.json with embedding length 1536
# Processed file review_499.json with embedding length 1536
# Processed file review_5.json with embedding length 1536
# Processed file review_50.json with embedding length 1536
# Processed file review_500.json with embedding length 1536
# Processed file review_501.json with embedding length 1536
# Processed file review_502.json with embedding length 1536
# Processed file review_503.json with embedding length 1536
# Processed file review_504.json with embedding length 1536
# Processed file review_505.json with embedding length 1536
# Processed file review_506.json with embedding length 1536
# Processed file review_507.json with embedding length 1536
# Processed file review_508.json with embedding length 1536
# Processed file review_509.json with embedding length 1536
# Processed file review_51.json with embedding length 1536
# Processed file review_510.json with embedding length 1536
# Processed file review_511.json with embedding length 1536
# Processed file review_512.json with embedding length 1536
# Processed file review_513.json with embedding length 1536
# Processed file review_514.json with embedding length 1536
# Processed file review_515.json with embedding length 1536
# Processed file review_516.json with embedding length 1536
# Processed file review_517.json with embedding length 1536
# Processed file review_518.json with embedding length 1536
# Processed file review_519.json with embedding length 1536
# Processed file review_52.json with embedding length 1536
# Processed file review_520.json with embedding length 1536
# Processed file review_521.json with embedding length 1536
# Processed file review_522.json with embedding length 1536
# Processed file review_523.json with embedding length 1536
# Processed file review_524.json with embedding length 1536
# Processed file review_525.json with embedding length 1536
# Processed file review_526.json with embedding length 1536
# Processed file review_527.json with embedding length 1536
# Processed file review_528.json with embedding length 1536
# Processed file review_529.json with embedding length 1536
# Processed file review_53.json with embedding length 1536
# Processed file review_530.json with embedding length 1536
# Processed file review_531.json with embedding length 1536
# Processed file review_532.json with embedding length 1536
# Processed file review_533.json with embedding length 1536
# Processed file review_534.json with embedding length 1536
# Processed file review_535.json with embedding length 1536
# Processed file review_536.json with embedding length 1536
# Processed file review_537.json with embedding length 1536
# Processed file review_538.json with embedding length 1536
# Processed file review_539.json with embedding length 1536
# Processed file review_54.json with embedding length 1536
# Processed file review_540.json with embedding length 1536
# Processed file review_541.json with embedding length 1536
# Processed file review_542.json with embedding length 1536
# Processed file review_543.json with embedding length 1536
# Processed file review_544.json with embedding length 1536
# Processed file review_545.json with embedding length 1536
# Processed file review_546.json with embedding length 1536
# Processed file review_547.json with embedding length 1536
# Processed file review_548.json with embedding length 1536
# Processed file review_549.json with embedding length 1536
# Processed file review_55.json with embedding length 1536
# Processed file review_550.json with embedding length 1536
# Processed file review_551.json with embedding length 1536
# Processed file review_552.json with embedding length 1536
# Processed file review_553.json with embedding length 1536
# Processed file review_554.json with embedding length 1536
# Processed file review_555.json with embedding length 1536
# Processed file review_556.json with embedding length 1536
# Processed file review_557.json with embedding length 1536
# Processed file review_558.json with embedding length 1536
# Processed file review_559.json with embedding length 1536
# Processed file review_56.json with embedding length 1536
# Processed file review_560.json with embedding length 1536
# Processed file review_561.json with embedding length 1536
# Processed file review_562.json with embedding length 1536
# Processed file review_563.json with embedding length 1536
# Processed file review_564.json with embedding length 1536
# Processed file review_565.json with embedding length 1536
# Processed file review_566.json with embedding length 1536
# Processed file review_567.json with embedding length 1536
# Processed file review_568.json with embedding length 1536
# Processed file review_569.json with embedding length 1536
# Processed file review_57.json with embedding length 1536
# Processed file review_570.json with embedding length 1536
# Processed file review_571.json with embedding length 1536
# Processed file review_572.json with embedding length 1536
# Processed file review_573.json with embedding length 1536
# Processed file review_574.json with embedding length 1536
# Processed file review_575.json with embedding length 1536
# Processed file review_576.json with embedding length 1536
# Processed file review_577.json with embedding length 1536
# Processed file review_578.json with embedding length 1536
# Processed file review_579.json with embedding length 1536
# Processed file review_58.json with embedding length 1536
# Processed file review_580.json with embedding length 1536
# Processed file review_581.json with embedding length 1536
# Processed file review_582.json with embedding length 1536
# Processed file review_583.json with embedding length 1536
# Processed file review_584.json with embedding length 1536
# Processed file review_585.json with embedding length 1536
# Processed file review_586.json with embedding length 1536
# Processed file review_587.json with embedding length 1536
# Processed file review_588.json with embedding length 1536
# Processed file review_589.json with embedding length 1536
# Processed file review_59.json with embedding length 1536
# Processed file review_590.json with embedding length 1536
# Processed file review_591.json with embedding length 1536
# Processed file review_592.json with embedding length 1536
# Processed file review_593.json with embedding length 1536
# Processed file review_594.json with embedding length 1536
# Processed file review_595.json with embedding length 1536
# Processed file review_596.json with embedding length 1536
# Processed file review_597.json with embedding length 1536
# Processed file review_598.json with embedding length 1536
# Processed file review_599.json with embedding length 1536
# Processed file review_6.json with embedding length 1536
# Processed file review_60.json with embedding length 1536
# Processed file review_600.json with embedding length 1536
# Processed file review_601.json with embedding length 1536
# Processed file review_602.json with embedding length 1536
# Processed file review_603.json with embedding length 1536
# Processed file review_604.json with embedding length 1536
# Processed file review_605.json with embedding length 1536
# Processed file review_606.json with embedding length 1536
# Processed file review_607.json with embedding length 1536
# Processed file review_608.json with embedding length 1536
# Processed file review_609.json with embedding length 1536
# Processed file review_61.json with embedding length 1536
# Processed file review_610.json with embedding length 1536
# Processed file review_611.json with embedding length 1536
# Processed file review_612.json with embedding length 1536
# Processed file review_613.json with embedding length 1536
# Processed file review_614.json with embedding length 1536
# Processed file review_615.json with embedding length 1536
# Processed file review_616.json with embedding length 1536
# Processed file review_617.json with embedding length 1536
# Processed file review_618.json with embedding length 1536
# Processed file review_619.json with embedding length 1536
# Processed file review_62.json with embedding length 1536
# Processed file review_620.json with embedding length 1536
# Processed file review_621.json with embedding length 1536
# Processed file review_622.json with embedding length 1536
# Processed file review_623.json with embedding length 1536
# Processed file review_624.json with embedding length 1536
# Processed file review_625.json with embedding length 1536
# Processed file review_626.json with embedding length 1536
# Processed file review_627.json with embedding length 1536
# Processed file review_628.json with embedding length 1536
# Processed file review_629.json with embedding length 1536
# Processed file review_63.json with embedding length 1536
# Processed file review_630.json with embedding length 1536
# Processed file review_631.json with embedding length 1536
# Processed file review_632.json with embedding length 1536
# Processed file review_633.json with embedding length 1536
# Processed file review_634.json with embedding length 1536
# Processed file review_635.json with embedding length 1536
# Processed file review_636.json with embedding length 1536
# Processed file review_637.json with embedding length 1536
# Processed file review_638.json with embedding length 1536
# Processed file review_639.json with embedding length 1536
# Processed file review_64.json with embedding length 1536
# Processed file review_640.json with embedding length 1536
# Processed file review_641.json with embedding length 1536
# Processed file review_642.json with embedding length 1536
# Processed file review_643.json with embedding length 1536
# Processed file review_644.json with embedding length 1536
# Processed file review_645.json with embedding length 1536
# Processed file review_646.json with embedding length 1536
# Processed file review_647.json with embedding length 1536
# Processed file review_648.json with embedding length 1536
# Processed file review_649.json with embedding length 1536
# Processed file review_65.json with embedding length 1536
# Processed file review_650.json with embedding length 1536
# Processed file review_651.json with embedding length 1536
# Processed file review_652.json with embedding length 1536
# Processed file review_653.json with embedding length 1536
# Processed file review_654.json with embedding length 1536
# Processed file review_655.json with embedding length 1536
# Processed file review_656.json with embedding length 1536
# Processed file review_657.json with embedding length 1536
# Processed file review_658.json with embedding length 1536
# Processed file review_659.json with embedding length 1536
# Processed file review_66.json with embedding length 1536
# Processed file review_660.json with embedding length 1536
# Processed file review_661.json with embedding length 1536
# Processed file review_662.json with embedding length 1536
# Processed file review_663.json with embedding length 1536
# Processed file review_664.json with embedding length 1536
# Processed file review_665.json with embedding length 1536
# Processed file review_666.json with embedding length 1536
# Processed file review_667.json with embedding length 1536
# Processed file review_668.json with embedding length 1536
# Processed file review_669.json with embedding length 1536
# Processed file review_67.json with embedding length 1536
# Processed file review_670.json with embedding length 1536
# Processed file review_671.json with embedding length 1536
# Processed file review_672.json with embedding length 1536
# Processed file review_673.json with embedding length 1536
# Processed file review_674.json with embedding length 1536
# Processed file review_675.json with embedding length 1536
# Processed file review_676.json with embedding length 1536
# Processed file review_677.json with embedding length 1536
# Processed file review_678.json with embedding length 1536
# Processed file review_679.json with embedding length 1536
# Processed file review_68.json with embedding length 1536
# Processed file review_680.json with embedding length 1536
# Processed file review_681.json with embedding length 1536
# Processed file review_682.json with embedding length 1536
# Processed file review_683.json with embedding length 1536
# Processed file review_684.json with embedding length 1536
# Processed file review_685.json with embedding length 1536
# Processed file review_686.json with embedding length 1536
# Processed file review_687.json with embedding length 1536
# Processed file review_688.json with embedding length 1536
# Processed file review_689.json with embedding length 1536
# Processed file review_69.json with embedding length 1536
# Processed file review_690.json with embedding length 1536
# Processed file review_691.json with embedding length 1536
# Processed file review_692.json with embedding length 1536
# Processed file review_693.json with embedding length 1536
# Processed file review_694.json with embedding length 1536
# Processed file review_695.json with embedding length 1536
# Processed file review_696.json with embedding length 1536
# Processed file review_697.json with embedding length 1536
# Processed file review_698.json with embedding length 1536
# Processed file review_699.json with embedding length 1536
# Processed file review_7.json with embedding length 1536
# Processed file review_70.json with embedding length 1536
# Processed file review_700.json with embedding length 1536
# Processed file review_701.json with embedding length 1536
# Processed file review_702.json with embedding length 1536
# Processed file review_703.json with embedding length 1536
# Processed file review_704.json with embedding length 1536
# Processed file review_705.json with embedding length 1536
# Processed file review_706.json with embedding length 1536
# Processed file review_707.json with embedding length 1536
# Processed file review_708.json with embedding length 1536
# Processed file review_709.json with embedding length 1536
# Processed file review_71.json with embedding length 1536
# Processed file review_710.json with embedding length 1536
# Processed file review_711.json with embedding length 1536
# Processed file review_712.json with embedding length 1536
# Processed file review_713.json with embedding length 1536
# Processed file review_714.json with embedding length 1536
# Processed file review_715.json with embedding length 1536
# Processed file review_716.json with embedding length 1536
# Processed file review_717.json with embedding length 1536
# Processed file review_718.json with embedding length 1536
# Processed file review_719.json with embedding length 1536
# Processed file review_72.json with embedding length 1536
# Processed file review_720.json with embedding length 1536
# Processed file review_721.json with embedding length 1536
# Processed file review_722.json with embedding length 1536
# Processed file review_723.json with embedding length 1536
# Processed file review_724.json with embedding length 1536
# Processed file review_725.json with embedding length 1536
# Processed file review_726.json with embedding length 1536
# Processed file review_727.json with embedding length 1536
# Processed file review_728.json with embedding length 1536
# Processed file review_729.json with embedding length 1536
# Processed file review_73.json with embedding length 1536
# Processed file review_730.json with embedding length 1536
# Processed file review_731.json with embedding length 1536
# Processed file review_732.json with embedding length 1536
# Processed file review_733.json with embedding length 1536
# Processed file review_734.json with embedding length 1536
# Processed file review_735.json with embedding length 1536
# Processed file review_736.json with embedding length 1536
# Processed file review_737.json with embedding length 1536
# Processed file review_738.json with embedding length 1536
# Processed file review_739.json with embedding length 1536
# Processed file review_74.json with embedding length 1536
# Processed file review_740.json with embedding length 1536
# Processed file review_741.json with embedding length 1536
# Processed file review_742.json with embedding length 1536
# Processed file review_743.json with embedding length 1536
# Processed file review_744.json with embedding length 1536
# Processed file review_745.json with embedding length 1536
# Processed file review_746.json with embedding length 1536
# Processed file review_747.json with embedding length 1536
# Processed file review_748.json with embedding length 1536
# Processed file review_749.json with embedding length 1536
# Processed file review_75.json with embedding length 1536
# Processed file review_750.json with embedding length 1536
# Processed file review_751.json with embedding length 1536
# Processed file review_752.json with embedding length 1536
# Processed file review_753.json with embedding length 1536
# Processed file review_754.json with embedding length 1536
# Processed file review_755.json with embedding length 1536
# Processed file review_756.json with embedding length 1536
# Processed file review_757.json with embedding length 1536
# Processed file review_758.json with embedding length 1536
# Processed file review_759.json with embedding length 1536
# Processed file review_76.json with embedding length 1536
# Processed file review_760.json with embedding length 1536
# Processed file review_761.json with embedding length 1536
# Processed file review_762.json with embedding length 1536
# Processed file review_763.json with embedding length 1536
# Processed file review_764.json with embedding length 1536
# Processed file review_765.json with embedding length 1536
# Processed file review_766.json with embedding length 1536
# Processed file review_767.json with embedding length 1536
# Processed file review_768.json with embedding length 1536
# Processed file review_769.json with embedding length 1536
# Processed file review_77.json with embedding length 1536
# Processed file review_770.json with embedding length 1536
# Processed file review_771.json with embedding length 1536
# Processed file review_772.json with embedding length 1536
# Processed file review_773.json with embedding length 1536
# Processed file review_774.json with embedding length 1536
# Processed file review_775.json with embedding length 1536
# Processed file review_776.json with embedding length 1536
# Processed file review_777.json with embedding length 1536
# Processed file review_778.json with embedding length 1536
# Processed file review_779.json with embedding length 1536
# Processed file review_78.json with embedding length 1536
# Processed file review_780.json with embedding length 1536
# Processed file review_781.json with embedding length 1536
# Processed file review_782.json with embedding length 1536
# Processed file review_783.json with embedding length 1536
# Processed file review_784.json with embedding length 1536
# Processed file review_785.json with embedding length 1536
# Processed file review_786.json with embedding length 1536
# Processed file review_787.json with embedding length 1536
# Processed file review_788.json with embedding length 1536
# Processed file review_789.json with embedding length 1536
# Processed file review_79.json with embedding length 1536
# Processed file review_790.json with embedding length 1536
# Processed file review_791.json with embedding length 1536
# Processed file review_792.json with embedding length 1536
# Processed file review_793.json with embedding length 1536
# Processed file review_794.json with embedding length 1536
# Processed file review_795.json with embedding length 1536
# Processed file review_796.json with embedding length 1536
# Processed file review_797.json with embedding length 1536
# Processed file review_798.json with embedding length 1536
# Processed file review_799.json with embedding length 1536
# Processed file review_8.json with embedding length 1536
# Processed file review_80.json with embedding length 1536
# Processed file review_800.json with embedding length 1536
# Processed file review_801.json with embedding length 1536
# Processed file review_802.json with embedding length 1536
# Processed file review_803.json with embedding length 1536
# Processed file review_804.json with embedding length 1536
# Processed file review_805.json with embedding length 1536
# Processed file review_806.json with embedding length 1536
# Processed file review_807.json with embedding length 1536
# Processed file review_808.json with embedding length 1536
# Processed file review_809.json with embedding length 1536
# Processed file review_81.json with embedding length 1536
# Processed file review_810.json with embedding length 1536
# Processed file review_811.json with embedding length 1536
# Processed file review_812.json with embedding length 1536
# Processed file review_813.json with embedding length 1536
# Processed file review_814.json with embedding length 1536
# Processed file review_815.json with embedding length 1536
# Processed file review_816.json with embedding length 1536
# Processed file review_817.json with embedding length 1536
# Processed file review_818.json with embedding length 1536
# Processed file review_819.json with embedding length 1536
# Processed file review_82.json with embedding length 1536
# Processed file review_820.json with embedding length 1536
# Processed file review_821.json with embedding length 1536
# Processed file review_822.json with embedding length 1536
# Processed file review_823.json with embedding length 1536
# Processed file review_824.json with embedding length 1536
# Processed file review_825.json with embedding length 1536
# Processed file review_826.json with embedding length 1536
# Processed file review_827.json with embedding length 1536
# Processed file review_828.json with embedding length 1536
# Processed file review_829.json with embedding length 1536
# Processed file review_83.json with embedding length 1536
# Processed file review_830.json with embedding length 1536
# Processed file review_831.json with embedding length 1536
# Processed file review_832.json with embedding length 1536
# Processed file review_833.json with embedding length 1536
# Processed file review_834.json with embedding length 1536
# Processed file review_835.json with embedding length 1536
# Processed file review_836.json with embedding length 1536
# Processed file review_837.json with embedding length 1536
# Processed file review_838.json with embedding length 1536
# Processed file review_839.json with embedding length 1536
# Processed file review_84.json with embedding length 1536
# Processed file review_840.json with embedding length 1536
# Processed file review_841.json with embedding length 1536
# Processed file review_842.json with embedding length 1536
# Processed file review_843.json with embedding length 1536
# Processed file review_844.json with embedding length 1536
# Processed file review_845.json with embedding length 1536
# Processed file review_846.json with embedding length 1536
# Processed file review_847.json with embedding length 1536
# Processed file review_848.json with embedding length 1536
# Processed file review_849.json with embedding length 1536
# Processed file review_85.json with embedding length 1536
# Processed file review_850.json with embedding length 1536
# Processed file review_851.json with embedding length 1536
# Processed file review_852.json with embedding length 1536
# Processed file review_853.json with embedding length 1536
# Processed file review_854.json with embedding length 1536
# Processed file review_855.json with embedding length 1536
# Processed file review_856.json with embedding length 1536
# Processed file review_857.json with embedding length 1536
# Processed file review_858.json with embedding length 1536
# Processed file review_859.json with embedding length 1536
# Processed file review_86.json with embedding length 1536
# Processed file review_860.json with embedding length 1536
# Processed file review_861.json with embedding length 1536
# Processed file review_862.json with embedding length 1536
# Processed file review_863.json with embedding length 1536
# Processed file review_864.json with embedding length 1536
# Processed file review_865.json with embedding length 1536
# Processed file review_866.json with embedding length 1536
# Processed file review_867.json with embedding length 1536
# Processed file review_868.json with embedding length 1536
# Processed file review_869.json with embedding length 1536
# Processed file review_87.json with embedding length 1536
# Processed file review_870.json with embedding length 1536
# Processed file review_871.json with embedding length 1536
# Processed file review_872.json with embedding length 1536
# Processed file review_873.json with embedding length 1536
# Processed file review_874.json with embedding length 1536
# Processed file review_875.json with embedding length 1536
# Processed file review_876.json with embedding length 1536
# Processed file review_877.json with embedding length 1536
# Processed file review_878.json with embedding length 1536
# Processed file review_879.json with embedding length 1536
# Processed file review_88.json with embedding length 1536
# Processed file review_880.json with embedding length 1536
# Processed file review_881.json with embedding length 1536
# Processed file review_882.json with embedding length 1536
# Processed file review_883.json with embedding length 1536
# Processed file review_884.json with embedding length 1536
# Processed file review_885.json with embedding length 1536
# Processed file review_886.json with embedding length 1536
# Processed file review_887.json with embedding length 1536
# Processed file review_888.json with embedding length 1536
# Processed file review_889.json with embedding length 1536
# Processed file review_89.json with embedding length 1536
# Processed file review_890.json with embedding length 1536
# Processed file review_891.json with embedding length 1536
# Processed file review_892.json with embedding length 1536
# Processed file review_893.json with embedding length 1536
# Processed file review_894.json with embedding length 1536
# Processed file review_895.json with embedding length 1536
# Processed file review_896.json with embedding length 1536
# Processed file review_897.json with embedding length 1536
# Processed file review_898.json with embedding length 1536
# Processed file review_899.json with embedding length 1536
# Processed file review_9.json with embedding length 1536
# Processed file review_90.json with embedding length 1536
# Processed file review_900.json with embedding length 1536
# Processed file review_901.json with embedding length 1536
# Processed file review_902.json with embedding length 1536
# Processed file review_903.json with embedding length 1536
# Processed file review_904.json with embedding length 1536
# Processed file review_905.json with embedding length 1536
# Processed file review_906.json with embedding length 1536
# Processed file review_907.json with embedding length 1536
# Processed file review_908.json with embedding length 1536
# Processed file review_909.json with embedding length 1536
# Processed file review_91.json with embedding length 1536
# Processed file review_910.json with embedding length 1536
# Processed file review_911.json with embedding length 1536
# Processed file review_912.json with embedding length 1536
# Processed file review_913.json with embedding length 1536
# Processed file review_914.json with embedding length 1536
# Processed file review_915.json with embedding length 1536
# Processed file review_916.json with embedding length 1536
# Processed file review_917.json with embedding length 1536
# Processed file review_918.json with embedding length 1536
# Processed file review_919.json with embedding length 1536
# Processed file review_92.json with embedding length 1536
# Processed file review_920.json with embedding length 1536
# Processed file review_921.json with embedding length 1536
# Processed file review_922.json with embedding length 1536
# Processed file review_923.json with embedding length 1536
# Processed file review_924.json with embedding length 1536
# Processed file review_925.json with embedding length 1536
# Processed file review_926.json with embedding length 1536
# Processed file review_927.json with embedding length 1536
# Processed file review_928.json with embedding length 1536
# Processed file review_929.json with embedding length 1536
# Processed file review_93.json with embedding length 1536
# Processed file review_930.json with embedding length 1536
# Processed file review_931.json with embedding length 1536
# Processed file review_932.json with embedding length 1536
# Processed file review_933.json with embedding length 1536
# Processed file review_934.json with embedding length 1536
# Processed file review_935.json with embedding length 1536
# Processed file review_936.json with embedding length 1536
# Processed file review_937.json with embedding length 1536
# Processed file review_938.json with embedding length 1536
# Processed file review_939.json with embedding length 1536
# Processed file review_94.json with embedding length 1536
# Processed file review_940.json with embedding length 1536
# Processed file review_941.json with embedding length 1536
# Processed file review_942.json with embedding length 1536
# Processed file review_943.json with embedding length 1536
# Processed file review_944.json with embedding length 1536
# Processed file review_945.json with embedding length 1536
# Processed file review_946.json with embedding length 1536
# Processed file review_947.json with embedding length 1536
# Processed file review_948.json with embedding length 1536
# Processed file review_949.json with embedding length 1536
# Processed file review_95.json with embedding length 1536
# Processed file review_950.json with embedding length 1536
# Processed file review_951.json with embedding length 1536
# Processed file review_952.json with embedding length 1536
# Processed file review_953.json with embedding length 1536
# Processed file review_954.json with embedding length 1536
# Processed file review_955.json with embedding length 1536
# Processed file review_956.json with embedding length 1536
# Processed file review_957.json with embedding length 1536
# Processed file review_958.json with embedding length 1536
# Processed file review_959.json with embedding length 1536
# Processed file review_96.json with embedding length 1536
# Processed file review_960.json with embedding length 1536
# Processed file review_961.json with embedding length 1536
# Processed file review_962.json with embedding length 1536
# Processed file review_963.json with embedding length 1536
# Processed file review_964.json with embedding length 1536
# Processed file review_965.json with embedding length 1536
# Processed file review_966.json with embedding length 1536
# Processed file review_967.json with embedding length 1536
# Processed file review_968.json with embedding length 1536
# Processed file review_969.json with embedding length 1536
# Processed file review_97.json with embedding length 1536
# Processed file review_970.json with embedding length 1536
# Processed file review_971.json with embedding length 1536
# Processed file review_972.json with embedding length 1536
# Processed file review_973.json with embedding length 1536
# Processed file review_974.json with embedding length 1536
# Processed file review_975.json with embedding length 1536
# Processed file review_976.json with embedding length 1536
# Processed file review_977.json with embedding length 1536
# Processed file review_978.json with embedding length 1536
# Processed file review_979.json with embedding length 1536
# Processed file review_98.json with embedding length 1536
# Processed file review_980.json with embedding length 1536
# Processed file review_981.json with embedding length 1536
# Processed file review_982.json with embedding length 1536
# Processed file review_983.json with embedding length 1536
# Processed file review_984.json with embedding length 1536
# Processed file review_985.json with embedding length 1536
# Processed file review_986.json with embedding length 1536
# Processed file review_987.json with embedding length 1536
# Processed file review_988.json with embedding length 1536
# Processed file review_989.json with embedding length 1536
# Processed file review_99.json with embedding length 1536
# Processed file review_990.json with embedding length 1536
# Processed file review_991.json with embedding length 1536
# Processed file review_992.json with embedding length 1536
# Processed file review_993.json with embedding length 1536
# Processed file review_994.json with embedding length 1536
# Processed file review_995.json with embedding length 1536
# Processed file review_996.json with embedding length 1536
# Processed file review_997.json with embedding length 1536
# Processed file review_998.json with embedding length 1536
# Processed file review_999.json with embedding length 1536

# %% [markdown]
# ### Step 1 - Converting CSV to JSON

# %%
import csv
import json
import uuid
import os

# %%
raw_reviews_file = "../../ai-foundry-trg-data/hotel_reviews_1000.csv"
transformed_dir = "../data/transformed"

raw_reviews = open(raw_reviews_file, "r").readlines()

if not os.path.exists(transformed_dir):
    os.makedirs(transformed_dir)

# %%
def process_reviews(file_path):
    with open(file_path, 'r', newline='', encoding='utf-8') as csvfile:
        # Read the first line to get the header
        header = next(csv.reader(csvfile))

        # Create a mapping of expected column names to actual column names
        column_mapping = {
            'dateAdded': 'dateAdded',
            'city': 'city',
            'hotel_name': 'name',
            'hotel_state': 'province',
            'review_text': 'reviews.text',
            'review_title': 'reviews.title'
        }

        # Find the index of each required column
        column_indices = {}
        for expected_name, actual_name in column_mapping.items():
            try:
                column_indices[expected_name] = header.index(actual_name)
            except ValueError:
                print(
                    f"Warning: Column '{actual_name}' not found in the CSV. Some data may be missing.")

        # Reset file pointer to the beginning
        csvfile.seek(0)

        # Skip the header row
        next(csvfile)

        # Use csv.reader instead of DictReader
        reader = csv.reader(csvfile)

        for i, row in enumerate(reader, start=1):
            review_json = {}
            for key, index in column_indices.items():
                if index < len(row):
                    review_json[key] = row[index]
                else:
                    # or None, depending on your preference
                    review_json[key] = ""

            # Generate a unique identifier
            review_json['id'] = str(uuid.uuid4())

            # print(json.dumps(review_json, indent=2))
            print(f"processed record [{i}] with id [{review_json['id']}]")

            with open(f"{transformed_dir}/review_{i}.json", "w+") as f:
                json.dump(review_json, f, indent=2)

# %%
process_reviews(raw_reviews_file)

print(f"Processed {len(raw_reviews) - 1} reviews and saved to {transformed_dir}")
print("All reviews have been processed and saved as individual JSON files.")
# Out:
# processed record [1] with id [14e42e6a-d6ba-475f-86a5-13e1c82bed94]
# processed record [2] with id [4b9bc073-68e7-4060-8d22-df04be2c3f30]
# processed record [3] with id [de654721-47f5-4477-8f47-e39ada410a84]
# processed record [4] with id [e4d2963f-3347-4b87-9295-63f5ef45654d]
# processed record [5] with id [36c4c145-5b33-4446-b2f2-6737d3ab8d7d]
# processed record [6] with id [7dc09d04-49e1-44c7-a620-913ffda35d7b]
# processed record [7] with id [39d7635f-322f-447f-8077-98b373f805e2]
# processed record [8] with id [ac020a85-b465-479b-83ab-aa42f8607fac]
# processed record [9] with id [56911a67-e3e3-440c-ad8a-7ec55ad107e6]
# processed record [10] with id [6568d61e-5fcd-4a6e-a05b-92a1d9696708]
# processed record [11] with id [82ac4aad-2ccf-4cff-b104-b6b3f8ce7e03]
# processed record [12] with id [15d51527-b176-4399-992f-becfb728ac27]
# processed record [13] with id [a79531c0-4ee5-4c32-ba40-f7f794b55c7a]
# processed record [14] with id [6a78cc76-b82c-43f3-b0f3-675679639304]
# processed record [15] with id [1a3cd246-2bc8-4488-86b3-04d4a60f97ed]
# processed record [16] with id [0c7f4ec5-3a65-4507-b7c0-190a6e7954a7]
# processed record [17] with id [22e82547-97ab-4189-a964-367fe2a30b71]
# processed record [18] with id [0838f04a-a822-40ba-94d3-d4457c7540cf]
# processed record [19] with id [1b386abf-dd46-4259-8cce-aa03e5ef55ad]
# processed record [20] with id [606d2e78-2dea-4429-86c1-28d0275f28f6]
# processed record [21] with id [0869fe32-ec6e-4ed5-9cdc-99ab9c3ba163]
# processed record [22] with id [3ab15ac8-1a54-4d43-894f-0f1136e973b0]
# processed record [23] with id [1f2d0668-f4e6-4f72-83a8-59dc72648b90]
# processed record [24] with id [f702d0c1-2ebb-4c85-b050-6adac4de89ad]
# processed record [25] with id [af1eeade-e053-4a15-b3a1-f1a202602a49]
# processed record [26] with id [ce163eeb-4182-49a5-969e-8f5baf5c7515]
# processed record [27] with id [bfb3f93f-4113-44d3-a034-b888166f79bd]
# processed record [28] with id [ca93b68e-bba5-4944-949b-62dbce76a6bb]
# processed record [29] with id [0b887ba5-aae6-4ead-947b-d44d4e35bfbd]
# processed record [30] with id [9cb38daa-39d7-4168-bd7a-51a5d7990464]
# processed record [31] with id [27cb4349-0d3b-4745-a842-06468bf5f731]
# processed record [32] with id [784ffe70-fe41-421c-b1bc-e74faceae6d1]
# processed record [33] with id [74e0a5dd-c560-478e-85ee-90313b0d0bb6]
# processed record [34] with id [0f87b27f-531f-4288-883a-5b5d5294d64c]
# processed record [35] with id [a2c01625-aba8-406b-b69d-335646f60f1f]
# processed record [36] with id [c4c46f43-b4b8-4c09-825c-cd3b7414ff2d]
# processed record [37] with id [0921971f-38f1-4591-8aa7-dd8a2cddd2b1]
# processed record [38] with id [ac5e729b-4c4b-46b3-b66e-9ce1497aebbd]
# processed record [39] with id [f32bb0fd-40b5-4d72-a7a9-3d11b75dd19a]
# processed record [40] with id [94d3dd6e-62a9-4d0c-a864-75dec1f9e6d6]
# processed record [41] with id [535703e3-2eab-4845-a2f1-1544ed4a6e2a]
# processed record [42] with id [e8474c72-cb22-436f-a8a0-981c1d7b99ee]
# processed record [43] with id [7b620a10-7220-415f-bcfa-cf8b1f118bdc]
# processed record [44] with id [91155cc3-f485-4024-83ea-f5a3aa80aca2]
# processed record [45] with id [8dedf7f5-d9a4-4fd9-8a26-9b2bad2338f1]
# processed record [46] with id [26f31fd5-1fa9-4760-b664-04521eaa5c71]
# processed record [47] with id [d2b4a1cd-a94c-48f7-b8a0-f55d81816a37]
# processed record [48] with id [61971a47-1774-4fa0-921f-741544652d6e]
# processed record [49] with id [fdbb5ff1-e00a-433e-9600-fde62cc16524]
# processed record [50] with id [3e8178fb-7fbc-4815-9047-0f35dd03c694]
# processed record [51] with id [5626208f-7952-41f7-ae21-8b48e8e5fde9]
# processed record [52] with id [4dafe14a-5541-4f82-8a6f-811cef1b2af9]
# processed record [53] with id [ec87f9af-0c5e-4380-a3d4-de24fd655b5b]
# processed record [54] with id [fb41c1c7-0286-4fe6-b9fe-b33a65a842c2]
# processed record [55] with id [37cc3691-ff74-43bd-b0d0-e8ecd9dd907c]
# processed record [56] with id [b834198e-80d3-4d06-86bb-cfbb3ca3863e]
# processed record [57] with id [c138a770-3c3a-48aa-9d01-341e53576555]
# processed record [58] with id [7df14249-e612-4ade-9166-be4272f25923]
# processed record [59] with id [1bd82488-f538-48f4-aa9c-e88e3bda4a6d]
# processed record [60] with id [7cf76521-fdf5-4799-aedb-a6b2b72ab4af]
# processed record [61] with id [aca683a9-fc05-45a7-961b-4d760c053a79]
# processed record [62] with id [7ff20c76-9483-4eb6-a99f-727d29daa461]
# processed record [63] with id [0eb41cc2-ec5c-4079-bcf0-265cf8ea2c7d]
# processed record [64] with id [ab0b4c9d-5b3b-4699-8493-4fa7e5608c1d]
# processed record [65] with id [4a1e55d5-a1a9-4a50-8c0b-e9afc57007ee]
# processed record [66] with id [8c008af3-dd45-4ef2-89b1-c96b391e06d0]
# processed record [67] with id [59aebd68-94cd-4926-bd8d-1d1e09043065]
# processed record [68] with id [cc40a85c-e16c-4e83-8cc7-40f8837465b0]
# processed record [69] with id [0ab3cb8c-63ca-4a23-b299-639fb6c0c54b]
# processed record [70] with id [9b35480c-a604-4bcd-bf4a-77a92dd625f8]
# processed record [71] with id [ed10f0b4-d28d-470d-befe-2b69f498d528]
# processed record [72] with id [682fa0fd-8bdf-4dad-862c-7735c1971635]
# processed record [73] with id [c61af0e7-c95c-40de-808c-a3c21f4f0c01]
# processed record [74] with id [831e3197-93ff-448c-ab56-15c794e620d1]
# processed record [75] with id [e278c10a-c524-4777-8c4a-426e4d75c6b4]
# processed record [76] with id [d76d2dc0-6ec8-47d9-a54d-023a80676238]
# processed record [77] with id [078ec5e0-6b41-48e9-8b7c-6e98e9c36d5b]
# processed record [78] with id [def4c715-3ac1-4e26-a993-432e36235bcf]
# processed record [79] with id [58f5c750-7c42-4af3-93f2-07f5d0dc0c2e]
# processed record [80] with id [e0bf44fd-2ab2-43a3-a382-d89f06b1afc9]
# processed record [81] with id [22b3979a-d931-45d8-903e-fe06b3e0a034]
# processed record [82] with id [84e9578d-e461-45f6-aa42-077dc3cae60c]
# processed record [83] with id [25875c47-cb69-4fb1-ac75-f7a15245aa91]
# processed record [84] with id [2b67e81d-4cbf-4ebb-b748-a65a2675c560]
# processed record [85] with id [358ad067-c3fe-47da-b917-f14da9f8940e]
# processed record [86] with id [93e7291c-be1e-4b2b-ae8b-8b99c2f5f6bd]
# processed record [87] with id [315dc66d-2304-4edb-b964-976c4d91363d]
# processed record [88] with id [baea9a92-0f14-4f3f-918e-ddff8c6f0c7a]
# processed record [89] with id [35c3b57a-f15b-44f3-9ced-8efbd67a7f67]
# processed record [90] with id [fdf7b46c-76b0-4775-afe9-e50f93da7484]
# processed record [91] with id [952ad8b2-4392-4f1e-b79c-9d6f1df2f824]
# processed record [92] with id [ed4c45a0-8766-4528-825e-b18ce2ba7e97]
# processed record [93] with id [b65857eb-ba39-4198-9712-35504a13d88f]
# processed record [94] with id [e398291b-60a2-4cd2-b3a9-6129a583dbba]
# processed record [95] with id [f4643510-40ff-4c47-aec9-3fe1f5b87fc5]
# processed record [96] with id [3bb0936e-5714-4dcf-bf42-b9796dc62ac3]
# processed record [97] with id [7d9ba3be-3715-4daf-84a8-9be0af2f9405]
# processed record [98] with id [cc4fc888-a3a7-403e-855c-3a429c79d514]
# processed record [99] with id [21122313-a801-4eac-bbe0-a2500289fd4f]
# processed record [100] with id [461af970-9417-4f1a-9ea9-ec10e442eabd]
# processed record [101] with id [ee9c5ff6-4179-4f8a-9779-75d3b981d14a]
# processed record [102] with id [0bba0933-fa07-4cc0-82d3-cc5838cf29b9]
# processed record [103] with id [50302474-fb09-4674-8067-7de3653e6b6a]
# processed record [104] with id [13eb73c3-781d-4f06-97e9-ea4bdf9313c2]
# processed record [105] with id [c30bb5fa-0832-4ac2-81b1-11e2b07887f3]
# processed record [106] with id [bd6c873a-9a2c-4476-8296-bd276a11a3c1]
# processed record [107] with id [6f9fd28f-2cd2-48ba-a5a6-1469af403720]
# processed record [108] with id [2440b76b-6e67-41bc-86a0-ad98b32bf713]
# processed record [109] with id [1637969b-b6c2-4d86-90fa-0ce0d0cc05ac]
# processed record [110] with id [43454e21-1855-4be7-acbd-2e88009481df]
# processed record [111] with id [79ebcf95-befc-4e03-a3e6-b08300300774]
# processed record [112] with id [414913af-f393-4c91-b97e-4c87106f9ecb]
# processed record [113] with id [6dd1a8b3-683f-42f5-887a-6c81dfbbd146]
# processed record [114] with id [ce7e02d8-8307-4742-a444-3ed7b8f27dc0]
# processed record [115] with id [a54e8251-5c0a-40b3-9b20-b07b4c8c9131]
# processed record [116] with id [713cd090-7462-42ba-b367-25ab8d113184]
# processed record [117] with id [489e66c9-0289-43bb-a817-895d862df3d6]
# processed record [118] with id [3d2ffdf1-2db8-4247-b5f5-4ac6399ee6bc]
# processed record [119] with id [390a5fae-3361-4fa0-acd0-69dc9811d417]
# processed record [120] with id [4562f549-36a9-43d2-ada8-780a07f63ae8]
# processed record [121] with id [3c38ffe2-6742-4b7e-818c-e90684938a09]
# processed record [122] with id [154fd4d2-5b21-4c2e-a0a7-3cca6f0904ed]
# processed record [123] with id [6e3b6034-3c7d-4870-857e-0c8bdb0b0fd5]
# processed record [124] with id [595c1e49-7c37-46b4-abc3-30a6277cb0b9]
# processed record [125] with id [58d020d4-aa22-4c91-b740-5db8bf69bae4]
# processed record [126] with id [8e220b50-6065-4891-a08c-09477e5d9dbd]
# processed record [127] with id [2a0ce00b-2a54-4969-a5f5-5df0b74a088b]
# processed record [128] with id [5a14f29f-ab55-4197-86a1-6a04cb194656]
# processed record [129] with id [7c1648c1-1753-4e9a-81e6-33e765e7fc15]
# processed record [130] with id [55392232-586f-4823-a551-4f024c956807]
# processed record [131] with id [34814c46-cb02-4c03-b0db-d698949e8f1f]
# processed record [132] with id [f3b71f4f-2426-4f27-a17d-f06e35124eb7]
# processed record [133] with id [0557180f-cb7a-47aa-80ce-3d8e19d4265f]
# processed record [134] with id [7b1a1326-9bc5-491d-ae82-ff8935854220]
# processed record [135] with id [b41d8299-e465-40e5-832d-0d5b3a0b5cb9]
# processed record [136] with id [893be522-d2d3-4ff7-87da-5d709120f8e6]
# processed record [137] with id [729256bc-c99a-4f04-adab-95296837680b]
# processed record [138] with id [bb3444c3-dea5-402e-9954-8c50c4f5165b]
# processed record [139] with id [27415060-82f7-43f5-b40d-4bedcb8dc818]
# processed record [140] with id [bfa9c3be-296c-4b12-9a97-036f581820d6]
# processed record [141] with id [b6601361-1e7c-49df-92df-197b8e7bf5e4]
# processed record [142] with id [1baec4c0-4760-4fb5-a68c-b73a7b37bf8c]
# processed record [143] with id [c91c77e5-c4a1-43d8-9e8f-3f1e1a23517d]
# processed record [144] with id [96276e11-b90a-4459-beb9-369eeeae1d1c]
# processed record [145] with id [6e066096-2563-487c-b3bd-60310a065ec2]
# processed record [146] with id [0564a8b2-d753-49d1-888e-808cdcac23ac]
# processed record [147] with id [d318f501-00f4-4191-8283-d7429609b03c]
# processed record [148] with id [b8710fdb-7bd7-4fa7-bfd9-535d09472790]
# processed record [149] with id [2dedeffe-421f-4562-8501-4f17a58afbc6]
# processed record [150] with id [b311cf7c-8ad4-4d5b-b047-dd54039697cc]
# processed record [151] with id [c390c381-542d-4dad-94d0-51e9e0bc5318]
# processed record [152] with id [7830a532-1579-4b1b-aebf-27d88b7b67d4]
# processed record [153] with id [048d0bc4-6f0b-47d0-9be3-1cd1dedf7d6b]
# processed record [154] with id [d5a76675-8116-4580-90ee-420a569578a8]
# processed record [155] with id [aae639f0-8ec6-4cb1-a374-3e4a40e3c814]
# processed record [156] with id [de3a60ea-4b36-445a-949e-572d0930c045]
# processed record [157] with id [56514d28-70c8-4979-9070-52c208eda25c]
# processed record [158] with id [a14d28f4-af3d-4357-9997-ac98d0abb7ec]
# processed record [159] with id [30762b12-8f6d-48f8-97fb-5f33d130ba15]
# processed record [160] with id [0ef114dc-a4e7-47af-8ca9-46beca83c23c]
# processed record [161] with id [a863db7a-781f-4735-9167-eb8fea47649b]
# processed record [162] with id [dd2f6e71-cace-46db-9ba3-b70c2cd15c4e]
# processed record [163] with id [46eaf523-9d9d-41e7-aed7-3e91b57e62ed]
# processed record [164] with id [6c810236-009c-41d9-ac13-6bbd6fa743cc]
# processed record [165] with id [ace6175c-a447-4c96-ade9-8e9a91ad3e5c]
# processed record [166] with id [99b3282c-c437-48f0-a1dd-459224d56393]
# processed record [167] with id [2cc13ca4-b8e6-4afe-91dd-8a044c99a90b]
# processed record [168] with id [73a8aa47-d6a8-49ac-96bc-f789c1c220ca]
# processed record [169] with id [92a40d2e-64d5-4297-a043-af93c19befa4]
# processed record [170] with id [d0fad516-6f81-4b52-964c-ecdd05526e3a]
# processed record [171] with id [b33f2e58-513f-4e14-84b4-4f6e4db29490]
# processed record [172] with id [a3b8750c-27b2-40be-8120-4e9e6c8d5270]
# processed record [173] with id [6c263695-4cc9-4fb5-b555-f6aa1f9214c1]
# processed record [174] with id [8c890bed-ac62-426a-b402-5bbc6147910c]
# processed record [175] with id [caaa69f2-0114-4658-ae52-f6a432e6129f]
# processed record [176] with id [c9b221ac-deae-4d86-af16-9a6bf7d835bc]
# processed record [177] with id [a7f45fe7-3151-419e-b221-d005b4d421ce]
# processed record [178] with id [67df1d55-a571-4a0a-b089-cf5eac8bdc82]
# processed record [179] with id [579e6746-5271-4aec-8def-2877917d15ab]
# processed record [180] with id [ae45a653-20af-4370-a53e-48f9e7de4cbd]
# processed record [181] with id [8330d1ab-2086-422c-8bf9-b06bbfbcfec5]
# processed record [182] with id [5ff2e529-ba7a-4f95-9c36-397c6ff166a7]
# processed record [183] with id [836b998a-8965-4812-9d72-846d10eab79f]
# processed record [184] with id [690565d7-6d5e-467d-8318-7ff12b78237b]
# processed record [185] with id [9607bddc-c99a-4599-9645-9fba882811a7]
# processed record [186] with id [a9bffb50-e04c-4e5c-a738-be050b2d83be]
# processed record [187] with id [47219407-0c02-4484-a5dc-d7f8c381f0a6]
# processed record [188] with id [65ca60c5-523a-4246-a64b-6e4f3cbd0cfe]
# processed record [189] with id [5fe8d607-cbee-478c-9419-adf02b939934]
# processed record [190] with id [b3f0a554-adc2-4d60-bc1d-df7886382b14]
# processed record [191] with id [56b263f5-9437-423a-b6af-d2de3a6ad2de]
# processed record [192] with id [dffe9d52-46a5-4878-b857-b2a713b431a7]
# processed record [193] with id [3cee05e3-7a12-4c4e-9ba9-18d646dd5044]
# processed record [194] with id [d84da218-261f-425e-b520-c34098a54ca7]
# processed record [195] with id [386b7b24-4649-432a-b935-67f9c7a37e16]
# processed record [196] with id [418fb4e7-7904-469f-baf4-aa14617fbc67]
# processed record [197] with id [ffddcb65-6cc4-4a78-81e1-33d50c0dfeb0]
# processed record [198] with id [4dbf3b4b-0b30-4af3-9439-6b4f2409262a]
# processed record [199] with id [bd7a1697-1c3e-4ba0-a447-7f0b8633e4e3]
# processed record [200] with id [580e5cac-49a5-4b4d-8ccb-4002245aa4f4]
# processed record [201] with id [725a16fb-2eb9-4d11-b6ce-89d477b2be54]
# processed record [202] with id [35aa92ed-ef39-420e-bbaa-963c660dc5c8]
# processed record [203] with id [46f3a02c-34f2-4434-a57c-3478f28ea68b]
# processed record [204] with id [199c1f50-5f0f-4fe1-aa7c-d2909505e213]
# processed record [205] with id [03c015d7-9591-4023-be13-4a5f489bebf4]
# processed record [206] with id [d1e365e2-16e1-4577-b6ba-0a5024706cc0]
# processed record [207] with id [18d0fa8f-76ff-45ea-8010-3c4c1b835312]
# processed record [208] with id [f486a710-9378-4c39-b4f2-24319b761701]
# processed record [209] with id [883e2de0-0a7e-4817-a460-6a6a05ad09df]
# processed record [210] with id [e142d7e9-590a-4d03-8752-90a1609790ab]
# processed record [211] with id [3e1659ca-7ef0-4594-a4c1-d07245bda754]
# processed record [212] with id [0df20f6d-ebd3-451a-bf32-7a4e4739929c]
# processed record [213] with id [433f2bd1-aa10-45c6-a59d-d871a3eb98c3]
# processed record [214] with id [7849fa47-3715-439a-af23-2aa9080bd249]
# processed record [215] with id [ddc7dead-6ea2-45ea-8569-8caf648671cb]
# processed record [216] with id [4367a186-0605-4864-80fc-3d6bfbe99595]
# processed record [217] with id [e73d06a6-920b-47ca-b2d7-02979877f0b6]
# processed record [218] with id [780f0fb4-9d7b-4f9d-94c0-0f36ef9ee680]
# processed record [219] with id [934f0349-20d0-4527-8c96-2d7c5fdef246]
# processed record [220] with id [2db3d052-9b30-4190-8df8-ad5f32ccf86f]
# processed record [221] with id [663e1cab-94ac-40f1-b5e1-b495a950d51d]
# processed record [222] with id [f98aa100-7bc5-40de-987c-b2d39d2cc430]
# processed record [223] with id [5c8ea7ff-692d-40a5-a487-8e4bf4712d88]
# processed record [224] with id [6147c527-a3a4-44de-b459-fe62e4fef52c]
# processed record [225] with id [1859db14-f3f9-4ea5-8be4-ac7e4547c8a3]
# processed record [226] with id [5178eea1-0f06-4779-b94c-87b20ce6d3c4]
# processed record [227] with id [9d32a0cb-0150-46f6-bb80-fe30abb8d3a1]
# processed record [228] with id [4cb33976-e9f8-4a23-a121-584e2e097b0c]
# processed record [229] with id [3d7ead04-4017-471f-a2a5-f313c5f8f730]
# processed record [230] with id [2ccefce8-9d6e-4110-bc7b-7b6b0f22e504]
# processed record [231] with id [b8c9c021-dcde-44bc-9d7e-fa407784dbce]
# processed record [232] with id [34a645aa-b459-4790-af0e-859d3257f7d2]
# processed record [233] with id [289a3925-c483-4d51-8c8a-de9ff12cc0f6]
# processed record [234] with id [93ccdd69-509b-407a-9d01-32370e919017]
# processed record [235] with id [072c42d0-4be1-4ff3-8d33-dccfa2c7b992]
# processed record [236] with id [8834a49c-03b6-461f-80cd-2efc248b73d1]
# processed record [237] with id [ea0836e2-8a88-49ce-a08a-2de442f2db3e]
# processed record [238] with id [f5d0e5fc-f17a-477b-924b-4105cfcde354]
# processed record [239] with id [e6e5ce51-5e46-4379-8ceb-ef9303b45fe9]
# processed record [240] with id [89ec397b-f65f-4dfe-8c67-9296bec63c4d]
# processed record [241] with id [acfe8301-7266-4cdd-9816-d240e1161c83]
# processed record [242] with id [0ad65e94-c598-4842-9d27-5375d00d0738]
# processed record [243] with id [203f8820-abef-4aaf-9f59-30fa04bc78a2]
# processed record [244] with id [6a2e1ec6-eb05-4c6e-9b3d-2426ce00fbc3]
# processed record [245] with id [6c333c65-8173-4574-ac58-04c7d3e1ef65]
# processed record [246] with id [098e5a76-89ed-4e2d-8305-20a68c38bddc]
# processed record [247] with id [319a4e9b-e996-4673-b468-e9c5b28b600a]
# processed record [248] with id [e99ce37c-b94c-49fd-94bd-0cf2897c5cb0]
# processed record [249] with id [ad4e1f16-d446-452e-ba9c-3fbefccd9c04]
# processed record [250] with id [55cf2124-454d-4365-9d85-ae58555bfa98]
# processed record [251] with id [d65fec49-e467-42d2-b2cb-352f3458bf5d]
# processed record [252] with id [6c427a99-6bd1-49fa-9aa3-d34c94f02d73]
# processed record [253] with id [1bbf0553-dcaf-4aa9-90c6-9dec58a7fb9a]
# processed record [254] with id [b52e761d-1028-4ff6-b024-3b3100166ea0]
# processed record [255] with id [cc26b746-fa5a-4dce-998f-62a45ede45dc]
# processed record [256] with id [fadb659c-859e-47a8-8f1a-e52329f7a6d4]
# processed record [257] with id [47c477a0-1592-4f9c-bf36-1981a5accf18]
# processed record [258] with id [92c37774-6278-4e7f-b2c3-77c3dee565cd]
# processed record [259] with id [f17b6c27-9b41-4ca6-a51b-d60cc25fb338]
# processed record [260] with id [2b39e1cf-1a61-43ed-a664-bb5f0bbfb990]
# processed record [261] with id [29be18bf-99f9-4bfa-ba21-72a87486c349]
# processed record [262] with id [3e429fac-abdc-4a28-8bc3-288b8b470b63]
# processed record [263] with id [bcc3333e-0dbf-4c45-8375-584422d5eb5a]
# processed record [264] with id [d8e36af0-5d3f-484c-b453-1761a1e246f0]
# processed record [265] with id [332bc924-9143-4cc7-b268-bad06119b2d0]
# processed record [266] with id [6d575ebb-3387-45ec-8070-a176dcd9055a]
# processed record [267] with id [fe0d2ab7-da3a-4748-882e-849bed1c9d2d]
# processed record [268] with id [78808bdc-de06-480c-aa59-82e7e8471898]
# processed record [269] with id [ac6076ce-2fe8-46fb-b03c-010d3ca215b4]
# processed record [270] with id [0a04b723-7286-46b2-aead-cf393ac350d2]
# processed record [271] with id [b6a419d1-dfde-4042-b68c-12322bfd8940]
# processed record [272] with id [f116ad8e-c18a-4a07-9f5b-bf9813eb1275]
# processed record [273] with id [42ef95a4-c32e-43d8-8bfe-a65e538f3aca]
# processed record [274] with id [47949478-760b-49df-a5ca-c48b59d6bb66]
# processed record [275] with id [7bbbcf5d-4dbe-419d-b486-5bd1bbdb8fbf]
# processed record [276] with id [91f8cf8f-e5d2-411f-a5b3-474ac3e637de]
# processed record [277] with id [9b8c21cf-c987-4f21-ad2b-bc62546b8233]
# processed record [278] with id [e37ed3b1-fd75-45c8-8fee-8db59d94af71]
# processed record [279] with id [6305fe6a-a487-4951-a52a-26319c809f6b]
# processed record [280] with id [4388313a-2d25-44b4-ba86-c27339549d42]
# processed record [281] with id [d4caf6d1-99f9-4523-b8ec-0f12f931d370]
# processed record [282] with id [95a1e64b-0e8a-4729-b2be-e17d70838b6d]
# processed record [283] with id [c6492e08-2c53-466d-b7af-1abfca2c08fa]
# processed record [284] with id [17d2f2b4-a206-47c7-a73c-f77a1e6de406]
# processed record [285] with id [cb1bd046-55eb-42a4-98fc-df4c2d8228dc]
# processed record [286] with id [b7563bd8-5b8e-4574-a63a-b6cfa2879064]
# processed record [287] with id [c877b2f4-aa42-4696-9930-747ea21660fa]
# processed record [288] with id [0920b5a7-5abf-4521-88fa-ce39de7eec65]
# processed record [289] with id [5b6c36bb-0789-4dd3-8a44-8411f2d07377]
# processed record [290] with id [d2a4fc4c-38b2-4910-b112-31bac03923d8]
# processed record [291] with id [987aa026-97a1-4c86-baa1-45cee1eca10f]
# processed record [292] with id [5a30b393-4d33-4378-96a1-60082031d874]
# processed record [293] with id [c27b6dad-7d35-460e-8044-4d901f7a381d]
# processed record [294] with id [6b55ca05-c22f-4b39-ba8c-683b15db9b40]
# processed record [295] with id [795eafe6-2db5-4eb1-93a2-ae2426a44b6a]
# processed record [296] with id [b2e91fba-3fb2-4580-bb6a-5d71b84c7709]
# processed record [297] with id [bc3bd926-9fca-4f0a-a7f1-303b1b47b3ad]
# processed record [298] with id [eed78d49-7786-4553-bbb8-4669566f09ab]
# processed record [299] with id [9d395f3a-7ec6-4250-90ca-45ead6bb2afd]
# processed record [300] with id [58fc46bf-7716-4c47-bc11-35b3cfcb3205]
# processed record [301] with id [374561a0-4c4f-4929-9559-7da7e8aed37c]
# processed record [302] with id [d86154ee-d429-4264-bb50-89d867e59989]
# processed record [303] with id [ea9aaa05-5532-470e-9d57-51777d25a936]
# processed record [304] with id [633e8529-e08b-40bd-8f8c-c85947658871]
# processed record [305] with id [66a4509e-ec75-4ffc-8f6a-d2e4340164cd]
# processed record [306] with id [39ee513c-ae2f-4133-8333-8ab49fad2f3c]
# processed record [307] with id [d329c146-dad7-44b4-a702-0e071e322e4b]
# processed record [308] with id [a936c48b-efda-4bfe-b9d2-8dbaac71ee09]
# processed record [309] with id [3358fc5a-baad-4f12-b63c-2b13c0d9cfa5]
# processed record [310] with id [2a367074-a2cd-40e6-913a-1b8b2da51b5e]
# processed record [311] with id [bd744fa6-aad8-4a43-bbab-71beda0c4ea4]
# processed record [312] with id [01927f52-4aa1-4198-af5e-dd46d4e0b771]
# processed record [313] with id [b6549cde-0ffa-4e35-820a-2ee0a06bfc16]
# processed record [314] with id [0d7919d3-8e5c-45b8-bb81-ed3754154774]
# processed record [315] with id [8d14098f-9be6-4af0-96b3-9f88ec92aae3]
# processed record [316] with id [ea2c0865-3aab-4ba1-91e2-966b49cb4cc7]
# processed record [317] with id [32cf6921-d6f8-422f-89f4-df39d486a5e4]
# processed record [318] with id [e14c96b6-d42b-45a6-aa37-e37507891288]
# processed record [319] with id [df6567d3-0d0e-49ac-9772-1fb8b3d26850]
# processed record [320] with id [537fe57a-c7a7-4798-a139-5ce4aea80912]
# processed record [321] with id [44b267cf-95d7-4cf4-8fbd-228fbe8037a8]
# processed record [322] with id [5b191514-0cfd-4282-bfa8-9e7808feeac7]
# processed record [323] with id [86e6700d-b4db-48f5-a7d4-54a79ccadfb7]
# processed record [324] with id [624ae704-ea7d-47d6-8b91-a48ff77169ed]
# processed record [325] with id [8c5545a7-f324-45bf-9336-ca15c939f3d1]
# processed record [326] with id [91551d79-ac22-4795-ac0b-0428d409f47e]
# processed record [327] with id [31813328-23d7-496e-bf05-6da4692664d1]
# processed record [328] with id [0daa9f1a-6b17-4f6a-bee5-ed3cf910feb6]
# processed record [329] with id [335c98d6-baae-4a1b-bca0-a42944b5fece]
# processed record [330] with id [70de8613-b61c-445d-a33d-744edc150cf6]
# processed record [331] with id [e4ae82f7-a047-450a-ab7f-948d820d9b8b]
# processed record [332] with id [999202d7-bb0f-4f07-a353-a39bc0a416e3]
# processed record [333] with id [0fa5d834-0064-4689-b599-2646f05840cc]
# processed record [334] with id [4901d722-4f22-4fa8-b811-01aa160e52b5]
# processed record [335] with id [772060ba-a8a1-4151-8ca9-c610a1a14621]
# processed record [336] with id [6b8dd830-9957-408f-890f-3a6e89707f90]
# processed record [337] with id [daf6d9fa-2f35-4fa3-9a0b-a6b873ac030e]
# processed record [338] with id [9b6d93f3-edee-4d28-bb0b-24a7978c284c]
# processed record [339] with id [f75cc1f5-e017-42e3-93a5-325882f14034]
# processed record [340] with id [2864e436-665e-48db-b01a-9374b4f03848]
# processed record [341] with id [0ae7785c-612a-43b2-a5e3-12d2b42de7a9]
# processed record [342] with id [2a5d2942-a8e9-43fe-bfce-4a27ac6b5433]
# processed record [343] with id [3afcceba-41a0-46d9-8d57-f3ad76101a01]
# processed record [344] with id [1b7a518e-371d-4ee1-86df-9b9ce7b9b891]
# processed record [345] with id [018c3a8b-489e-4c86-869c-42c34a1650fe]
# processed record [346] with id [a5f91bb1-c406-4e8f-bd77-74ac351f1177]
# processed record [347] with id [39aec478-72be-44b8-bdd9-b189b7d69d55]
# processed record [348] with id [d770add0-d9b5-4ef3-9371-f7ccf4b1953f]
# processed record [349] with id [0d324106-da3c-4f09-a905-c2ddccd0a760]
# processed record [350] with id [fed0a151-d9cd-4e67-a13f-1ea5d7d584b0]
# processed record [351] with id [62f5e8ca-7b57-4982-bf7c-c17338705cfe]
# processed record [352] with id [2009ac94-4eba-458e-bc74-c32321a03b81]
# processed record [353] with id [37b5a49c-c805-4db5-8232-5d9f82d3a1ab]
# processed record [354] with id [087ae12f-cafe-41a1-b9aa-b1248ae53a83]
# processed record [355] with id [ba9ba70f-4dd1-46e3-a93c-88959cead682]
# processed record [356] with id [e9126eb2-f9d6-47ce-89ca-e342fa9fae04]
# processed record [357] with id [654ca8e2-af7b-44df-a386-78c145c1fe61]
# processed record [358] with id [d80c85b3-1008-499a-9192-a01c0080bf77]
# processed record [359] with id [b5b02b7f-cb78-4877-b1a0-bfb141de30a9]
# processed record [360] with id [2d2735ea-d7ad-4107-a7ed-06e0665f0917]
# processed record [361] with id [daf91180-3104-4ae6-b351-d3eebcb4c526]
# processed record [362] with id [050aff29-8a69-48b6-9fc5-227545d5b0b8]
# processed record [363] with id [aac4270c-19a4-4a6b-a5c2-3530bcc3a2a2]
# processed record [364] with id [37c54dd6-f014-4c39-9eba-01783eb05477]
# processed record [365] with id [3471f54b-67bd-4145-97b2-4e4697aaf9fa]
# processed record [366] with id [7f2789d4-acad-43d3-b144-bc13dbfbabcb]
# processed record [367] with id [b2ad9646-3d7f-46ce-b9f6-95a57a9f5d88]
# processed record [368] with id [7cbc9f62-0b30-41af-9482-a9cf57db45d7]
# processed record [369] with id [706e4b75-29b4-44d7-8b6c-f3c3105ddeb8]
# processed record [370] with id [96d7aadb-e19d-46e1-8b8f-36a19ac86a36]
# processed record [371] with id [791a887b-9fe9-4d80-9c89-59800b8e278f]
# processed record [372] with id [bac62a7f-35ae-4889-8877-8588b334d79d]
# processed record [373] with id [08b8eac5-c50f-499d-ab8d-8a3a2f9fe08f]
# processed record [374] with id [11d98219-80e4-44d3-a9fb-d722553c418d]
# processed record [375] with id [845e9649-fb17-4d8e-9ce1-187dadd7477e]
# processed record [376] with id [d5191b7b-0705-4b21-82ac-fa13f2e49a55]
# processed record [377] with id [0768d7ad-2b3a-49cd-8739-6bf0e88b74b3]
# processed record [378] with id [ce2097d4-112f-4908-af92-66b1b82ec13f]
# processed record [379] with id [1f93f594-e953-497a-a348-a052ed60d9cf]
# processed record [380] with id [fcd38443-0ae4-470c-9f4e-e55205af3ed5]
# processed record [381] with id [be2aace4-03d4-4102-8f1f-b78a87749d4c]
# processed record [382] with id [d260681d-9947-453e-94d4-c9aa2b8fc551]
# processed record [383] with id [ed638692-be9f-4614-8904-8bcfb92d8c45]
# processed record [384] with id [ff9f2c57-4064-42a9-9015-e3f9477a10dc]
# processed record [385] with id [28c9b723-fb08-4c99-8de0-5c382b901266]
# processed record [386] with id [c090efba-0acd-4711-8fce-14b50cdb3d62]
# processed record [387] with id [98f9ea94-d16f-4886-ac09-b7f417c24927]
# processed record [388] with id [728aaba8-5f12-454f-8cba-9147f000370e]
# processed record [389] with id [e21d7148-c817-4110-b1b7-69717c935c72]
# processed record [390] with id [9f7282a1-3d42-455c-b1d6-16455e1f4121]
# processed record [391] with id [d61edc48-31d8-4899-8319-b4bf749ebabb]
# processed record [392] with id [402dda26-bc60-48f2-9d72-66c31b6f1327]
# processed record [393] with id [0d1164fb-cc3a-41fa-866d-4c13b668185d]
# processed record [394] with id [ebb74df7-6220-44f9-907f-0a533b0bd542]
# processed record [395] with id [173ca05d-4816-43a0-b340-871c1491b67a]
# processed record [396] with id [3a0f988e-a4f5-4c04-81f9-89e651e2dbe3]
# processed record [397] with id [9b57e182-6ce1-4490-ad15-dc50ca3b16b2]
# processed record [398] with id [8e27ea3f-03cb-4f87-8141-90b36afdda68]
# processed record [399] with id [aefd9bd8-ee35-4f2c-aacb-857a31db219b]
# processed record [400] with id [8dc6ae06-eb5b-4303-be40-6599e37f9326]
# processed record [401] with id [13f8b352-f1ca-4939-be63-e10ac7b59649]
# processed record [402] with id [dec75f61-440b-4962-918e-99c9d1b4f4fa]
# processed record [403] with id [ccda6fa7-1e5b-4976-a6d9-4e080e15f15a]
# processed record [404] with id [7f828cc4-59b5-4a33-976c-f3ee71b62b27]
# processed record [405] with id [c85af186-7718-41a3-8f31-34db4ecaa629]
# processed record [406] with id [5f8eb4f8-04f9-4a43-9c42-0fd6c413bb90]
# processed record [407] with id [464b82cc-6024-48e5-8196-7035d876d299]
# processed record [408] with id [bd460d94-3947-4108-8cf8-03e9f061533c]
# processed record [409] with id [c8e60505-2847-4eca-b9d6-fe69ed9fc663]
# processed record [410] with id [73c2a93f-4117-4c05-8a78-0f1488cce416]
# processed record [411] with id [4784ba96-248c-4692-8d0e-e16753934ca5]
# processed record [412] with id [7179f4a6-227d-43eb-93d7-9c3d495170ee]
# processed record [413] with id [524506f9-920d-4382-baf6-a6ee34fb08a1]
# processed record [414] with id [041b70ff-d280-4cdf-97dd-93a9fd795376]
# processed record [415] with id [4a99a36f-3506-4886-a601-7e661c7fb105]
# processed record [416] with id [a3b324a2-37c5-4a72-8a7a-73c4815c23b0]
# processed record [417] with id [2d5e1fff-6709-4a18-92ea-e25f0d376d3e]
# processed record [418] with id [63362053-257a-4e60-937b-c1dbb381c8c0]
# processed record [419] with id [29936ae7-cf9c-4b03-9714-3bc9d13d8ed7]
# processed record [420] with id [5e1fd383-17fa-43c1-9966-77996c23676a]
# processed record [421] with id [aba156e4-f758-4c37-a7ab-98282e034a4b]
# processed record [422] with id [4e76ff31-938a-4866-b240-3d472e348ab6]
# processed record [423] with id [28fee44f-2b84-4e7c-9549-0f06f6e3ecd4]
# processed record [424] with id [159474dc-6a41-4ebf-a85a-72737b5f8415]
# processed record [425] with id [7a290907-24d3-456e-8e5e-4176271a966b]
# processed record [426] with id [078bdd15-7f12-4bc4-9001-1d53a6b312f5]
# processed record [427] with id [c82487e9-f1d2-4c24-93f3-97e74a9c40ef]
# processed record [428] with id [db7d220f-278c-493e-93ba-84566c5cea2d]
# processed record [429] with id [ef042e44-3136-4138-9086-42355caf2fe1]
# processed record [430] with id [e44106c3-8d18-46cb-bfdd-107b6d8f71de]
# processed record [431] with id [8e3faf1b-a5ff-46eb-a23f-6cbd375cc086]
# processed record [432] with id [bc8fe857-d188-4ccb-8551-a80f13b5f5f1]
# processed record [433] with id [b7422b6a-6825-4f7c-9dd2-431750281192]
# processed record [434] with id [2edb1c26-e4c8-4a26-917a-c97eda831fed]
# processed record [435] with id [26dd096c-1184-4122-a4b6-1a7fef8288e7]
# processed record [436] with id [b68be43f-99fe-4456-a146-3049fb956c5f]
# processed record [437] with id [3dd93318-86a0-4e72-85a6-a11f7f743209]
# processed record [438] with id [2604e2ef-b4f8-4a0a-aebe-d7762ed3dd2d]
# processed record [439] with id [893dcdf4-8ef7-407e-8d65-22505cd52d24]
# processed record [440] with id [ce8d1347-1cce-4ccb-9371-a98339933d19]
# processed record [441] with id [7937ed73-180b-4be5-9ab3-e8b3846cd9e4]
# processed record [442] with id [ef050be0-0049-4503-8acf-c5297658ea92]
# processed record [443] with id [17678a65-b3e9-4e9e-a6a7-fc42045cf12d]
# processed record [444] with id [da94b192-9d0d-4440-946d-84efea71b5ee]
# processed record [445] with id [8105607e-f6d4-44aa-969a-3231f0bdd3c8]
# processed record [446] with id [085ac6d3-de8d-47cc-a7c8-3631e64f770b]
# processed record [447] with id [6caa8fb2-8a56-4b86-acc3-a33cf2561158]
# processed record [448] with id [9bedc431-7a6b-4de0-a54d-1e78b2df68af]
# processed record [449] with id [d8c73c4d-7966-473a-b737-adced9b91409]
# processed record [450] with id [0be6b802-3f59-4143-b088-f8dac3b9b27f]
# processed record [451] with id [5bdc7fb0-707f-4a28-9da1-1f3f12160ced]
# processed record [452] with id [82e05e54-7cf9-400d-9421-f911d88c13c6]
# processed record [453] with id [b8b1d116-c2ec-4a52-b6f3-62aa764aff44]
# processed record [454] with id [b4431d6b-8e7b-44e7-9d46-e5246e7e4a94]
# processed record [455] with id [ddc49054-aec9-4dcb-9ce1-b2fcff32d293]
# processed record [456] with id [11bf9620-311b-49a8-ab22-ad24dae4d3d7]
# processed record [457] with id [967df695-ee97-4741-8d4f-462cc4c5fa0d]
# processed record [458] with id [41f4eb12-22ad-42dd-b235-e4401086c5f5]
# processed record [459] with id [671fc72d-5acc-48c5-98a5-0ccbd301e24a]
# processed record [460] with id [5892acbd-fac1-49bd-8854-ebef3f42429e]
# processed record [461] with id [51e65e23-9bf6-49ef-85b5-4e30ce27422e]
# processed record [462] with id [8971a3eb-40fd-4a7f-93bd-0cf56302d9ba]
# processed record [463] with id [41bf23a1-37ce-49f0-8503-13acad0b931a]
# processed record [464] with id [22e27563-bc47-4422-a0ff-800eb90c4ab7]
# processed record [465] with id [b1e0e04b-7167-43bf-b3be-3a6057e73dc7]
# processed record [466] with id [d694e479-996c-4603-99a8-e005d07ca78b]
# processed record [467] with id [ebb30d33-c80f-41fd-af37-2c5eac631b4e]
# processed record [468] with id [d05b2605-d6be-443e-925b-73ed20105f93]
# processed record [469] with id [8ed8157e-b26d-48f3-a20f-843d74b08f81]
# processed record [470] with id [ba012204-60cc-45ef-973a-bc81ba4a3fcb]
# processed record [471] with id [793ebfed-ddb7-4277-a0d6-42bdac3912d2]
# processed record [472] with id [21d1c303-47f0-4838-bb3e-9f11a9339059]
# processed record [473] with id [ee06b914-4c94-4ecf-97d7-54fc7ee64d05]
# processed record [474] with id [e3a1e300-8aff-47ff-92c8-fb1872d03032]
# processed record [475] with id [ef1a24ca-dc36-4bec-86ec-45d26ee37399]
# processed record [476] with id [0356ae66-99bb-4ed7-acf5-6a689345c683]
# processed record [477] with id [c0f7fb8b-537f-482a-b9cc-dd7aa754ee32]
# processed record [478] with id [ff49f5bc-0974-4c30-b811-a322b8427916]
# processed record [479] with id [3ef3da3f-dde6-4e28-a824-31b0ffdbdc8b]
# processed record [480] with id [dec7e1e4-4ed3-4925-99f5-a4cd26d05c3d]
# processed record [481] with id [6638f2d4-ad6b-440e-a033-ad251918e140]
# processed record [482] with id [84154fc1-aa15-43a1-abd9-a9df684c2705]
# processed record [483] with id [3510acc6-a650-469a-9b8e-5ed81ae9917d]
# processed record [484] with id [949ad6cb-6b2b-44cf-b402-aa3c33a49677]
# processed record [485] with id [3a9c7041-3bb1-49a3-bb4c-0435f4278750]
# processed record [486] with id [10ecf702-6c50-4d32-8e61-6ca41eed793c]
# processed record [487] with id [0bd7ef0a-6d87-461c-a258-60c50e23e2ba]
# processed record [488] with id [857353a5-f9aa-4da5-854f-5653448fe89c]
# processed record [489] with id [c75cdef0-c96d-4710-86e3-4be66b90769f]
# processed record [490] with id [693d8934-5b74-4d8a-a99a-07033d697f00]
# processed record [491] with id [dac6919c-b939-4dd8-8401-35386cf5f6eb]
# processed record [492] with id [c0922b23-3e0d-4393-89a1-e844b31c8da5]
# processed record [493] with id [44fc24ab-1e63-4257-8def-0ab6a283b3fd]
# processed record [494] with id [480ae3e3-e109-4605-b40c-713c1a9b63ec]
# processed record [495] with id [6772cbe9-1f81-4f42-96e4-25a7ea2f3c64]
# processed record [496] with id [80de7745-70af-47ce-b639-1fbed998a1a7]
# processed record [497] with id [eba40aa3-4df5-4930-95c9-edc43af3faf1]
# processed record [498] with id [af63a940-4ea0-4930-af88-e8eeaaa9fd39]
# processed record [499] with id [e121ea8e-2d12-4f95-8922-fe8836eba047]
# processed record [500] with id [127a189d-5740-43eb-85c8-e898f9f4eba2]
# processed record [501] with id [208af0dc-edd8-4821-8513-f0d57a71f4d8]
# processed record [502] with id [ef35d8e7-bb08-4e83-a883-6a1aad4c9d01]
# processed record [503] with id [f8e6145f-9edb-4df5-b897-16b89bcb2cd3]
# processed record [504] with id [fa036059-d45b-4843-89a8-20e0e8b863b1]
# processed record [505] with id [272d1bde-b22a-439d-92cb-8b41a05745ac]
# processed record [506] with id [73a18955-bd83-4377-bbf5-3ad0a77c0c69]
# processed record [507] with id [52b94438-de89-4b07-8f53-c61bdd68548f]
# processed record [508] with id [dab7a99b-91f3-44a3-a9f5-db96118907cf]
# processed record [509] with id [f1cffb89-dbb1-41f6-aede-fce29f364f54]
# processed record [510] with id [b7ffadf0-8bd3-4280-a508-da8c2c5b1075]
# processed record [511] with id [dde389f2-c44e-443f-9e3a-e2ba3cf67416]
# processed record [512] with id [78d3e83f-3dea-4ff2-835f-2fc89fc1a5a4]
# processed record [513] with id [7cf1f814-551f-4cb5-8224-1446625ca077]
# processed record [514] with id [78424623-5894-473c-946f-5134adf261db]
# processed record [515] with id [45321e84-e9d2-4def-a3d4-570fe72bebdf]
# processed record [516] with id [34f4dcad-f1a9-44ff-99ee-88b822576e05]
# processed record [517] with id [3004af93-9c5f-4de7-8823-7f7093394824]
# processed record [518] with id [8fee3362-f3f0-4174-bca1-3837a62ccb49]
# processed record [519] with id [3d278643-0405-462f-9937-ab5c4656647d]
# processed record [520] with id [ba5ff8c4-2b01-4a0b-882d-58e9f5ed4b6f]
# processed record [521] with id [db693130-fcca-486c-ba0e-4d9fd969c356]
# processed record [522] with id [c6d4dcb6-7261-48cc-af3c-a55f40eaa97c]
# processed record [523] with id [9b37f5b9-5f04-4811-a3bc-2d861eab7437]
# processed record [524] with id [667c4eb0-f161-48a7-959a-d94815df7b94]
# processed record [525] with id [5ffe7559-f916-4970-ae22-fe1294e2d14a]
# processed record [526] with id [eac110ea-dbfb-4001-8fc7-bfcd9d8bd534]
# processed record [527] with id [7aef2c0b-940b-4d17-bd84-052fb1258756]
# processed record [528] with id [2c8937a3-d86c-4656-bb0d-ae8fbf533145]
# processed record [529] with id [92561dbc-8af8-4fcf-9c15-67a4d1c6c12e]
# processed record [530] with id [b9290e75-31bd-44da-b011-ac5ee1f507ee]
# processed record [531] with id [98675fe0-78be-46ef-b839-fb55e7affc19]
# processed record [532] with id [1138e3cf-6d6c-49d8-ab79-bd440bdefc0b]
# processed record [533] with id [518121ed-8165-47e8-8ce7-8fa5c6352d7d]
# processed record [534] with id [ee44f7a3-4dc1-4b65-82c5-707e8f5331d9]
# processed record [535] with id [10e3d1fb-ce01-4c3f-aa73-90749844e957]
# processed record [536] with id [3fb42256-5668-458d-bc6a-9dee888930fd]
# processed record [537] with id [3a4715f4-f745-443f-9ede-7fc5b4913d51]
# processed record [538] with id [62393be2-30e5-4926-ae33-aa02b24ccb67]
# processed record [539] with id [25d5ea9f-dc19-49f0-b41e-f0c3120eb47a]
# processed record [540] with id [a3e7cbd0-0133-4095-9c8e-0c3738af4aaf]
# processed record [541] with id [9b9f2e34-0044-48aa-8919-6f5dfedbdfb7]
# processed record [542] with id [889b2a27-335a-4870-b5ab-565c4e600b70]
# processed record [543] with id [df7b278d-60cb-4dae-b9b6-241419c16319]
# processed record [544] with id [a88ed957-f1be-4a70-bf1f-7c365db22916]
# processed record [545] with id [c1321878-7cc3-427b-8aa7-26b7a6cda28b]
# processed record [546] with id [257b86ec-2df9-4208-8049-7820a5bd6d49]
# processed record [547] with id [00754f67-1cdd-420c-8482-4c01508fe507]
# processed record [548] with id [450fe9f4-41fc-4220-ac03-847b73c31d44]
# processed record [549] with id [fd8cc978-8e81-414a-a3e2-3d482377ba7f]
# processed record [550] with id [81b91177-d535-4613-9355-cb94a05c08f4]
# processed record [551] with id [3acbf9e1-4882-4ff0-80ef-18f2f343b8b3]
# processed record [552] with id [faa808c6-94ed-4caf-b767-48a51d4d7044]
# processed record [553] with id [b61efa40-0248-43c6-a0f8-1e6333a5d587]
# processed record [554] with id [a1b2ea29-a820-4cbc-9837-cbfe57b4042c]
# processed record [555] with id [3b43e51b-cf15-4620-a850-c55e1692c3b9]
# processed record [556] with id [fbeb979c-8294-4cc6-9451-b491be4d67e2]
# processed record [557] with id [6eb979ea-3a7e-4003-874e-f163c4f9efa1]
# processed record [558] with id [971ff9cd-fbb7-4b2d-84af-41826a9127e6]
# processed record [559] with id [37a9bc06-ade4-45a7-a68e-fa8e5b2cffb0]
# processed record [560] with id [d51aefe8-2b01-4899-b9b2-e973cc63a88c]
# processed record [561] with id [75cbe7e2-68f6-43eb-9171-7076f3017847]
# processed record [562] with id [0b43f84f-3b1e-4dd4-be9d-ea304b963f64]
# processed record [563] with id [63b17f6c-742b-4e1f-9f33-5bf217421708]
# processed record [564] with id [987939d4-94d1-4381-8af9-61d712f0e999]
# processed record [565] with id [bed43208-cd81-4c0c-ba8d-3076907b5c7b]
# processed record [566] with id [cf113b4d-71f7-4162-a72e-f0d0a2d21c09]
# processed record [567] with id [4ba7d303-d7dc-45cd-a1ed-7b4a55bfa8b7]
# processed record [568] with id [0a9a294a-7236-4b73-9207-10709fd1bb41]
# processed record [569] with id [5e1efa37-4005-49a4-b097-b0e4ea33fc9d]
# processed record [570] with id [7fab1737-d8b2-452b-85e3-18b62fb44ab1]
# processed record [571] with id [78b08900-9846-402e-a2cc-5559c30487b3]
# processed record [572] with id [a3e93898-98b1-4599-91f5-fc82a8b66ea2]
# processed record [573] with id [3709cc5a-1ecb-4868-b465-4ea149648964]
# processed record [574] with id [48dc3a1c-0beb-4dfb-8ef3-5a1c7d3e45aa]
# processed record [575] with id [03f28ce8-21b6-4c8e-8dee-2dc326484d91]
# processed record [576] with id [253d36bd-4f69-47b0-a7fe-99552e94fd89]
# processed record [577] with id [66ad6188-9db0-4e4c-b52a-2e8330ba2b66]
# processed record [578] with id [1ad97010-fa01-449f-8ace-6bb812d82c6d]
# processed record [579] with id [d007aff7-8a96-4aee-8657-356475bd2bf3]
# processed record [580] with id [f9c5584e-4e35-4af9-99c7-5bff589c3543]
# processed record [581] with id [45a08636-de7d-412d-8eac-9d52b791378f]
# processed record [582] with id [e8e8ba9d-d6cc-41c4-86d3-ff0927db0673]
# processed record [583] with id [7867a9aa-9eab-4114-8743-147aae6b2958]
# processed record [584] with id [81d1cbae-31c4-4f52-b03c-c2857f699d8c]
# processed record [585] with id [4a2b3b8b-d5d5-4af7-96f6-aeb35e85d31d]
# processed record [586] with id [5d6c37dd-8866-460c-8a02-b96a7eaefc7b]
# processed record [587] with id [12e9ca79-fab2-4a03-a69b-052e1ee33660]
# processed record [588] with id [cd53aa90-8e5d-4948-b9e5-1f9315590729]
# processed record [589] with id [1d2019c8-b6b2-41f0-a2b2-87c1ea6662c3]
# processed record [590] with id [3eab1acf-21ab-4738-a378-c93308cbd43f]
# processed record [591] with id [790cdf55-11a7-4400-bd08-c12825da4c2c]
# processed record [592] with id [4145d5fd-9ef5-4fa9-a4f8-961cdfb2195f]
# processed record [593] with id [eccbc75a-95bb-415c-9eae-f76a24fe0769]
# processed record [594] with id [67fd2111-7ef2-4b4b-87bf-0f41c6c7dfce]
# processed record [595] with id [3d08f256-786b-4759-a744-e1a75fd4094f]
# processed record [596] with id [40f60fdf-3334-4752-a4cf-39a5b17334f0]
# processed record [597] with id [29ccdd6b-5865-4758-aff6-ec2cd39493b6]
# processed record [598] with id [29346417-e670-4edb-86bb-3dd171780fb4]
# processed record [599] with id [1c8f6685-b151-4d29-8dc7-afb1b8c4702d]
# processed record [600] with id [858a8982-ee2d-4957-bdfa-198b21af44e5]
# processed record [601] with id [0270c784-4458-4537-bc14-87838be77de6]
# processed record [602] with id [76eeb4fd-09fa-457f-abdf-e0ec6386005a]
# processed record [603] with id [1e203bc5-5017-4312-a6f5-cab85cf447a5]
# processed record [604] with id [2b0c74e1-d0c1-4b50-9b31-e4397d5f9f2a]
# processed record [605] with id [dc35133a-329d-4e0c-81cb-b21040a7f1d8]
# processed record [606] with id [2537496f-4d0e-4ee3-8985-442657431d50]
# processed record [607] with id [64a3c7b4-7d13-4a63-b41f-75c541895a65]
# processed record [608] with id [53d7f0b8-b767-40da-b385-e0c2c7107763]
# processed record [609] with id [dc5b5547-65fa-42b9-9c78-f7cd805ea8da]
# processed record [610] with id [7d7aca9e-f23e-4189-8ed4-36a3e466706a]
# processed record [611] with id [27bd0785-8663-4b43-b076-1ea3716152e5]
# processed record [612] with id [70282d31-332d-492e-b290-9facb6c8b0bb]
# processed record [613] with id [6c996fbc-776a-4ae9-b568-afee697f304f]
# processed record [614] with id [519ba1de-a818-4d99-891e-54efddb6eafe]
# processed record [615] with id [178ed8f7-42ee-4665-9773-51928b889327]
# processed record [616] with id [5b362752-ae3f-4a42-a165-2491cf85c900]
# processed record [617] with id [d8c96ef6-5e02-41c1-b14f-75a2b8729fff]
# processed record [618] with id [4038dfa1-442b-40c4-84a8-14e67df0d93d]
# processed record [619] with id [268330b6-0757-4c1e-a78d-969d9cbbc07f]
# processed record [620] with id [ce867af4-26e7-45b3-b376-ea59719c4c20]
# processed record [621] with id [3ad8b27d-9609-4a68-a265-cbfe85207a92]
# processed record [622] with id [fc844e95-f937-4ed2-9d9d-ad9dc6db9f33]
# processed record [623] with id [d40e0d5d-7fde-4ed7-808d-f3968dfab78c]
# processed record [624] with id [9e4cd19e-0b7f-4d1c-a152-0b4faf8142dd]
# processed record [625] with id [62892ac3-761d-4fdb-ab2e-e5e9f3b11095]
# processed record [626] with id [1ce3600e-1694-466c-9502-d619cb377b85]
# processed record [627] with id [58b65b41-3a33-42df-a876-04fe0cbc378e]
# processed record [628] with id [f817b550-747e-4e3d-8f36-d7da5d9417bb]
# processed record [629] with id [f10f0100-f2cd-43e6-b996-efbfd0d07b81]
# processed record [630] with id [c377d21a-c745-4445-a109-099b18daefb2]
# processed record [631] with id [f64aa14e-b0de-43c6-9cb1-66be04771b4b]
# processed record [632] with id [0adfa747-e811-43fc-afd7-6b4e2c7ba230]
# processed record [633] with id [154939e1-3309-4852-beb0-779e725adc91]
# processed record [634] with id [2684ee1b-d783-4c7f-bee5-9c778983c8a5]
# processed record [635] with id [a37e4647-0969-4548-b6d8-b86b4bbe563d]
# processed record [636] with id [56e3bed6-9fc9-4139-a4f1-32215a759556]
# processed record [637] with id [30e2fc5d-5a14-4d1e-a845-a02b9ad56801]
# processed record [638] with id [8e35a9e6-4fd0-4017-b9b4-ffe067540f7e]
# processed record [639] with id [10ad5f31-0ad5-4210-ad24-f7b14c1dcea2]
# processed record [640] with id [d735d68f-5a50-4f3b-9b52-4ebe43bbd554]
# processed record [641] with id [2fa42594-9191-434c-b818-ff0a1781cd49]
# processed record [642] with id [7b4a727c-31e5-4fc4-b7eb-5cd980347766]
# processed record [643] with id [162b8cda-a7c8-4da0-b0dc-9a6732766740]
# processed record [644] with id [a3c56d6f-07b3-4030-a97e-2f593e1f9d5f]
# processed record [645] with id [275537b4-0c81-4716-b726-3856cdb1ce4f]
# processed record [646] with id [a6b24fab-fcbe-43c1-8a84-1131db3d3bec]
# processed record [647] with id [a19e8a84-e866-4452-8918-4817f32cf32e]
# processed record [648] with id [dc8a6c2e-cd18-40a2-a6b4-9b4f0ceced95]
# processed record [649] with id [3029ebbd-7f12-4de3-bbb5-6af101fe9435]
# processed record [650] with id [86ec1d20-5f94-4eff-adba-f1bf900d521d]
# processed record [651] with id [90637f29-c5ba-402d-958f-b8d8e044de50]
# processed record [652] with id [9e5cc0f5-39fe-43a4-b8c4-bd0b34c97df1]
# processed record [653] with id [b70cad75-f704-41ff-875a-3998d3591057]
# processed record [654] with id [9dbad475-6f3a-498a-8fa4-67dae443cf52]
# processed record [655] with id [dfe8bfe4-9dd9-4d55-a120-f9cbb952e47f]
# processed record [656] with id [8e669627-ce17-4391-aed5-4bc02fb1a7fb]
# processed record [657] with id [e9cdcb35-5861-4933-b26e-b9e10516e389]
# processed record [658] with id [43bb08af-0432-466c-8b0f-e7f6dfdadbd0]
# processed record [659] with id [d084aec4-f48a-45ef-bd18-50c3c6528399]
# processed record [660] with id [6824b64e-4f9c-4005-87c4-53fb3b9e0429]
# processed record [661] with id [3c01feaa-4230-4875-8f15-1e10e3340a53]
# processed record [662] with id [4df7e68d-c55e-4513-89eb-3ccf1d7f8ccc]
# processed record [663] with id [77280515-f4be-4350-bf71-5435fe2109a6]
# processed record [664] with id [ce8fef23-ca4d-4f0c-93a6-8aa3d62251b7]
# processed record [665] with id [a92543e8-ea32-4486-91c1-2bd78ffad179]
# processed record [666] with id [083f2d81-a46a-415f-8f08-c526f91e293c]
# processed record [667] with id [9cee33e7-fbaf-41c1-a118-b0eb5cc9bad6]
# processed record [668] with id [9dbf4fa0-88a1-4faf-93fa-c2ea08d9e434]
# processed record [669] with id [c1916039-20a9-4c42-97a4-5ff83a39bd06]
# processed record [670] with id [d17d4bee-8b38-47df-b82b-f4bb2ce2ab11]
# processed record [671] with id [4df80bda-a1a2-46be-838f-cbf6764ddb5a]
# processed record [672] with id [c1ebfc57-ef49-4927-a292-d0c1a3730431]
# processed record [673] with id [932b5eea-da8d-421c-b573-8bd8296d522b]
# processed record [674] with id [c63b0cf2-6e77-43ab-8bf9-f372e123d2b1]
# processed record [675] with id [46a74873-b10a-43d6-b242-2de95d29732d]
# processed record [676] with id [315f8d4d-09c6-4247-a49f-f197b11a1879]
# processed record [677] with id [e15c6aae-dfe6-4d0d-bcd2-2790869478e7]
# processed record [678] with id [46ed264a-3f4e-4f6a-9321-0b4033f330eb]
# processed record [679] with id [336d9e82-7d92-48dd-81ca-07edf4b08797]
# processed record [680] with id [c8032d29-cf56-4591-8c43-8c79320b1e6b]
# processed record [681] with id [f84bd9de-7a42-4224-8e35-10bf7c0a3987]
# processed record [682] with id [1fd807fc-ba77-4581-9635-a21c20e774d8]
# processed record [683] with id [9e924117-f233-4ffa-96bf-5a88cfb4263c]
# processed record [684] with id [44232fa7-98f2-4c79-81e1-81735a47c1e0]
# processed record [685] with id [9eb664d8-9181-4819-918f-ca9082e98bdb]
# processed record [686] with id [1c7f3b5f-20de-4568-a7f5-cd3e71356fa2]
# processed record [687] with id [bb9ea35e-3896-4340-a3df-146ff08194a9]
# ...
# processed record [774] with id [8fd1f4e7-9d54-40fd-83a0-55d0d4220d2f]
# processed record [775] with id [e6f3f4b5-a486-40d3-b4d0-a52b03d263e6]
# processed record [776] with id [3a875e37-6e3e-4e8a-b5c1-fc6cb520614f]
# processed record [777] with id [064eae55-63df-4052-ad4e-2b0a87392e51]
# processed record [778] with id [8c10108c-e59a-4ccf-a080-ae95f2b17d09]
# processed record [779] with id [4c5ab307-4418-4499-aaf6-e575cbef33d6]
# processed record [780] with id [a95e67ab-7d09-49e8-9f6f-3aeb936957e0]
# processed record [781] with id [e9d1ecfa-e081-4312-85c0-13ba717453e4]
# processed record [782] with id [2d4d39ed-6813-4ffb-afca-ea84e024ca88]
# processed record [783] with id [926f563a-e3a0-42b1-8509-41fc2cc485d5]
# processed record [784] with id [72ec023c-2860-42cf-ad96-5227a471f08b]
# processed record [785] with id [4d466b3a-acd6-4044-ac01-26bf76123f8e]
# processed record [786] with id [8726c1f5-4275-41b5-84ee-9a5c0466c7cb]
# processed record [787] with id [2dd5ce73-5d23-4020-b7d3-0491d97689f9]
# processed record [788] with id [b680f388-a707-49dd-88cc-9815dd1a56ac]
# processed record [789] with id [5b507f7a-e7f8-4921-a7ba-eafddb5a41fa]
# processed record [790] with id [ccff86f8-f649-495b-80a3-575d2b33f5a7]
# processed record [791] with id [d629f1b9-8090-4c59-847b-9a76cf62fcf8]
# processed record [792] with id [603a45b8-cede-4057-90f1-f77cd1e48d40]
# processed record [793] with id [7ff2e2cb-cad9-4a6d-8547-7b4d5fb1b213]
# processed record [794] with id [8cfd53ab-217e-433c-8624-d7e1d7228045]
# processed record [795] with id [4e257c8a-1d3e-46e5-9a4d-bd12a2a2bcca]
# processed record [796] with id [b00da33c-fceb-4dfb-a366-0cc940fa9047]
# processed record [797] with id [aaa75234-1b00-4657-9521-50c465c0c582]
# processed record [798] with id [144167e7-155a-4162-b8d1-6a10c5fa6fc5]
# processed record [799] with id [be554697-0cd1-49ef-8691-46599161f144]
# processed record [800] with id [d04e0acb-3237-4383-8169-c008b952f136]
# processed record [801] with id [ee64f87b-28c1-4c06-9913-04055c21f8f1]
# processed record [802] with id [a10a52db-5c5f-4f06-963a-17696c24ddf5]
# processed record [803] with id [ba2232fc-e9de-4eba-925c-a96bd9417fc4]
# processed record [804] with id [4e012788-b48c-40ec-b7a7-36481499ae5f]
# processed record [805] with id [b0a75b53-0e3b-44c6-9886-b6c44a9fb514]
# processed record [806] with id [e82db931-05fd-4a49-aab0-7ef12af85189]
# processed record [807] with id [1fe834dc-5cf6-416e-8022-99ca72151715]
# processed record [808] with id [f58e6ff9-b803-48aa-895f-c5145aecefc9]
# processed record [809] with id [88b5a420-a664-4da0-b4bd-b4ee61aa2c90]
# processed record [810] with id [393934a3-8a47-4ee6-82ea-d545952b3b8a]
# processed record [811] with id [4d7d75d1-9774-45ec-816e-0df3c9269761]
# processed record [812] with id [c6b00c42-8d22-43fc-ae82-21366127c161]
# processed record [813] with id [6ed238fb-c182-419d-bbc0-75a4d1d75df2]
# processed record [814] with id [6f5ad1cf-8c51-416b-8e7f-8aab8a185ec2]
# processed record [815] with id [d74be8bb-bfc6-41b5-bb71-2d21d642676d]
# processed record [816] with id [480d369b-87ab-4617-9ff7-700e005d64c1]
# processed record [817] with id [ae3aeb15-324e-470d-9e7b-46c351ed80dc]
# processed record [818] with id [a94c2452-3c39-40a6-b303-420784bc269e]
# processed record [819] with id [b0aa3dd0-f47f-460d-a729-7275844264ce]
# processed record [820] with id [b7204295-bb81-476d-aa30-8a780978e5aa]
# processed record [821] with id [5ffa196f-2953-4d67-9fe1-6db6a1d280ec]
# processed record [822] with id [c7527ecb-d3ce-4397-8da7-d7a9998d061b]
# processed record [823] with id [b5802449-27a1-45fe-9edd-76a1b71b85f1]
# processed record [824] with id [a24734e1-dda2-424f-bfd2-4f99723f09c2]
# processed record [825] with id [e29c40a3-d992-4639-b253-6ee9411d01a1]
# processed record [826] with id [04a980fc-710f-4e0f-bde0-7f3229b982c5]
# processed record [827] with id [64dd2fe5-4754-44cb-9d4d-7e1cc4acc237]
# processed record [828] with id [d4e37f4b-0e57-4bdd-8e73-081a480f9457]
# processed record [829] with id [775647cf-21cd-4e1f-b92b-88efb85a0a9f]
# processed record [830] with id [d29dcce9-c8c8-4634-a1a2-ce4db28e5dc5]
# processed record [831] with id [e3139974-d4c1-4957-9e59-2bee0006d3a5]
# processed record [832] with id [79a1044b-e83a-497d-8aa8-1d3bcdb35f98]
# processed record [833] with id [50b7a417-e2a5-4c39-8afd-38ecb0436456]
# processed record [834] with id [70a44c91-89cc-4f3b-9c93-688c36b49da2]
# processed record [835] with id [36386612-117f-47c3-a54c-7d5c3ce34629]
# processed record [836] with id [689aef06-4922-4666-897a-0d1703b57652]
# processed record [837] with id [9fefaeb9-58f3-40f0-a50d-c700320de809]
# processed record [838] with id [9cd30d00-6a31-476a-b995-481ca3334559]
# processed record [839] with id [c62cf9b6-ff94-4ebd-a82b-18c0352d3dd1]
# processed record [840] with id [276d694c-343e-4fd1-b2d1-b6080a42ed49]
# processed record [841] with id [69361e44-4316-48ef-b90f-c074102ada64]
# processed record [842] with id [d93896b7-d454-4dc8-89b9-93b161eab184]
# processed record [843] with id [c6d7166e-0f3e-4cc6-b577-f2b4f3e99488]
# processed record [844] with id [0e56c8f0-6b54-4f3d-8af4-79e3836930ab]
# processed record [845] with id [1631e872-7012-42fe-a321-4de33d558527]
# processed record [846] with id [ef05b8fb-ef23-4099-99d5-6f2b5c4a283d]
# processed record [847] with id [c3f918ce-b1d1-46ff-9ddb-42d17f961165]
# processed record [848] with id [42de6406-5323-4060-8503-a9cbe83a4ad7]
# processed record [849] with id [69185245-9920-4b11-8212-033e0a102d06]
# processed record [850] with id [76e43d51-49e9-447f-a67e-94df56e029c5]
# processed record [851] with id [b2f23b6b-4f5b-42b8-8d3d-c96596e80080]
# processed record [852] with id [6798f61f-e3fd-4698-8b75-edfdf038dead]
# processed record [853] with id [5200f9d3-5610-4e5e-8927-469d22b8e338]
# processed record [854] with id [e6d2c771-3aef-4840-9280-5852c11eef9d]
# processed record [855] with id [4da4435b-baa8-4087-ab46-2fc5086a2222]
# processed record [856] with id [f71270fa-6e03-4209-b1d6-23f98fc9ebf3]
# processed record [857] with id [ee3f4bae-58bf-41ec-98e5-c1525b2d8eb7]
# processed record [858] with id [3c6566f3-5866-437b-9bbf-72fdf3d7f745]
# processed record [859] with id [7bf56f0b-cbb9-44cb-92b5-1192d2acaed0]
# processed record [860] with id [fd92c16f-c8f9-4c36-b97a-19fb3fa52ef0]
# processed record [861] with id [4c8b4163-0c25-46cd-99e7-4709495faabc]
# processed record [862] with id [eb0b4e15-6bb3-4db0-9f77-76f35f60b637]
# processed record [863] with id [6890974c-3d07-478f-905b-571997070f08]
# processed record [864] with id [452da83d-a87d-4e69-ae15-f85d3db178f0]
# processed record [865] with id [9b7191cf-8196-4a0f-aa11-d75ad17691bd]
# processed record [866] with id [cfc09ce6-95c2-458f-a92c-f93a4d78e26f]
# processed record [867] with id [c0cde65d-f847-4a5a-ba68-4f7e65b02db2]
# processed record [868] with id [a44eb2eb-88e0-4f25-90ca-99dd2424abfe]
# processed record [869] with id [6276fb9a-c781-40c1-87fe-014fbd7f1e59]
# processed record [870] with id [fa54cdfb-7d05-4268-b8dc-61587feeb026]
# processed record [871] with id [ab082e7d-d0be-4f18-9f0d-ffc03e8cbbe6]
# processed record [872] with id [892619b4-270a-4876-81b7-425e54dd1d60]
# processed record [873] with id [c4d16b6b-c75f-448d-9ce7-32bab306b016]
# processed record [874] with id [37c75d49-3be1-49a9-9a62-794e6f36401a]
# processed record [875] with id [19d24c79-dbf7-442d-9a3f-e88c5c089547]
# processed record [876] with id [37396189-1cc9-4375-8ecb-61c6e68c343b]
# processed record [877] with id [a309f173-d10c-4904-9413-dd3269b66f1f]
# processed record [878] with id [1806d80d-341b-4c02-a0c1-ff84f44a30aa]
# processed record [879] with id [56486478-eb29-407d-a853-121b50758ee3]
# processed record [880] with id [c13b043e-696f-48fd-bc97-f39eb13c1f0f]
# processed record [881] with id [c808fef9-2e69-4328-90e6-b60bd6680ebc]
# processed record [882] with id [6b3bf9e4-f470-46d6-b3d5-fa0ff2ae740a]
# processed record [883] with id [a6810867-5cbe-4f19-ac6f-d4cabb619969]
# processed record [884] with id [1335c7d1-8082-4852-8eed-76ef82406b20]
# processed record [885] with id [3d1c6584-a8ca-445b-9b3c-dc5f35dbe067]
# processed record [886] with id [792dd88d-4c44-448e-95a6-666a984108bb]
# processed record [887] with id [7d958c23-5a0b-4e6a-af6b-e82c2fa15b26]
# processed record [888] with id [8caa88b0-936f-42a9-a23a-e45ecbaeb0ba]
# processed record [889] with id [584f49c7-38eb-423a-a521-9d561844a011]
# processed record [890] with id [b260cb8d-582b-4dc1-b7d4-86d2ab69f89a]
# processed record [891] with id [f61939db-0275-4dea-8ef8-93850d8fe855]
# processed record [892] with id [1da0c148-1839-4364-9e16-f9ce6c3edb5e]
# processed record [893] with id [e1d0871d-9f6d-40d4-b95a-612c1b4be0d0]
# processed record [894] with id [3e46e60d-ad3e-4b66-afa4-ce0822e8ac5e]
# processed record [895] with id [e4f1780f-7d84-4888-8f35-24b7f8e38ceb]
# processed record [896] with id [5e6436db-109d-4a51-9ecb-735554b0326f]
# processed record [897] with id [f95a53ac-57d7-420e-819a-8120ff714b0e]
# processed record [898] with id [63589628-968b-48f1-9aa0-fd97c2ef418b]
# processed record [899] with id [8a8fe12a-e14f-4ea0-a46b-569255ade9dc]
# processed record [900] with id [725396f4-9033-4cb9-98e7-c9b58eb320f9]
# processed record [901] with id [0daf546c-4edb-4159-bd62-f92b942dd025]
# processed record [902] with id [528511c3-2d2e-4ee0-a567-c612cc79bbd3]
# processed record [903] with id [7473a9ff-eee9-4134-8681-68a69e38d1bb]
# processed record [904] with id [85786a0b-c560-4b7a-9a29-4d150c98a260]
# processed record [905] with id [ef774220-efdc-4ff1-b46f-9b9b01707beb]
# processed record [906] with id [fca784aa-0504-4035-9799-710314525a77]
# processed record [907] with id [72b05658-0669-4b7f-b5be-671a109e5670]
# processed record [908] with id [8de17e36-8724-4457-a81e-09ef60d7687a]
# processed record [909] with id [44e88676-6c88-4afb-aaf0-ec75333b07a0]
# processed record [910] with id [5f119225-798b-47b9-9008-1ce73c4947f5]
# processed record [911] with id [1034027c-ba3f-45f0-ac43-340e6f5a324c]
# processed record [912] with id [9614795a-77b3-40a9-a59a-2bab7da84c34]
# processed record [913] with id [946624f6-c7dc-4643-b163-ef70a3deae0f]
# processed record [914] with id [431ac8f2-4274-4254-9561-053a9ef0144a]
# processed record [915] with id [18aeb47c-bd34-4fb0-8aae-f07a17cbfbd8]
# processed record [916] with id [d42c3f41-407a-4728-a561-a8b33c33bfe1]
# processed record [917] with id [8a8aa5e0-0179-4d40-be31-4c779b62a9e7]
# processed record [918] with id [45b57c22-a184-4379-b993-bc9021452448]
# processed record [919] with id [2ab26fe7-7d19-4f99-a942-d929d3dcfa2a]
# processed record [920] with id [f277a009-7adf-45b7-b675-d5281a1d4467]
# processed record [921] with id [ba706256-53b7-413a-9d4e-11fc3636e391]
# processed record [922] with id [7d35833d-5812-465e-a251-ad539bdf9703]
# processed record [923] with id [e0993b3e-8bd8-45d2-a1f1-5ccd8418e3f9]
# processed record [924] with id [71e3c65f-d97c-4f63-b3e5-5d6703c33ac8]
# processed record [925] with id [04bd6fee-e41c-496a-8d1c-171a09bf0dcb]
# processed record [926] with id [672e38d3-d6f9-435f-8b66-e1fc0a14ea5e]
# processed record [927] with id [1b1910f7-4dfd-415f-93d8-83df049e0bbb]
# processed record [928] with id [eacb06bc-b883-42cb-af90-66cfc680640f]
# processed record [929] with id [a684c91d-375b-4109-8b7d-14fff8e506b6]
# processed record [930] with id [4d3d0a6e-0d21-44d8-ba85-d868a4429dbd]
# processed record [931] with id [d1fa19ef-7cf2-421c-967b-bd262cad660e]
# processed record [932] with id [8574228a-1411-4a71-9583-590aa3079601]
# processed record [933] with id [143c8425-b11b-4bf4-98b8-858ec3d6d216]
# processed record [934] with id [1048948f-8050-45f0-9a13-dc04f30eed90]
# processed record [935] with id [f720b381-c743-41d0-909d-8f63f195edca]
# processed record [936] with id [f6e1b8d1-75ad-49bb-96a0-a7c4ebd1d58f]
# processed record [937] with id [a728e82a-9516-4fdb-bc7f-114dc4308492]
# processed record [938] with id [05f6e627-7d32-4ce3-b0c7-56998f2edabf]
# processed record [939] with id [651291b8-26cb-472f-8ca4-13af9ef84887]
# processed record [940] with id [b4115b9b-8b8b-433f-8b47-9aaa22b9a494]
# processed record [941] with id [04a4ccc4-e725-4798-bd04-1de43a5ba66a]
# processed record [942] with id [6ef19b58-9bad-427e-bd53-d0400d49ecc5]
# processed record [943] with id [d5d19aaa-8745-45c7-a7ab-6569846b8cc2]
# processed record [944] with id [51346a99-7821-4cdc-ae07-dcd52d415b61]
# processed record [945] with id [6d5e3bab-6e60-4248-958d-f7b1629e1f8a]
# processed record [946] with id [14b51d20-e987-4953-8242-01696b9707ac]
# processed record [947] with id [549062c3-8933-4b7f-ac1c-f01733d141c4]
# processed record [948] with id [e1d52fcc-64c5-4630-b9fc-8361569a6b75]
# processed record [949] with id [d3bcc7e0-811f-4c0a-8074-40f7d6277ea1]
# processed record [950] with id [1df292ec-9a79-4953-b7dd-d8162c21eee0]
# processed record [951] with id [ab33ec48-0996-4ee7-a890-0c4bdd816270]
# processed record [952] with id [22d09ca4-b9f8-42f4-b63a-9f096bba2abe]
# processed record [953] with id [4789ec1e-c434-4ea5-bfb0-8cadbe52b419]
# processed record [954] with id [f4dd1986-758a-4a2d-9fb6-f224fec6e6d6]
# processed record [955] with id [6a332c47-0058-4072-8eb8-f579e171ab20]
# processed record [956] with id [d83e0af1-3f08-4dd1-8829-98cb29115c98]
# processed record [957] with id [0cc47b90-b823-47f7-90e4-906ff0e7c3a9]
# processed record [958] with id [b30a695b-dea2-49f0-83f4-6d5b1712b1d6]
# processed record [959] with id [7e50325e-a488-4152-9885-e2b97a303fe3]
# processed record [960] with id [0256d06b-dcc4-4cfa-87ac-af64e6e40f53]
# processed record [961] with id [a5899d08-5663-4e4d-b22f-a0ffe18f9c4c]
# processed record [962] with id [0657e6d4-cb49-44e6-9700-205f9012084a]
# processed record [963] with id [d25d8c5f-806d-4e68-bf6c-dfa8290ecbc1]
# processed record [964] with id [978ca1db-add1-42f8-bfab-9cb506808fb2]
# processed record [965] with id [1dcf3995-02d6-4906-9fb0-c947fd56e273]
# processed record [966] with id [cbaa446d-0008-4a81-9b68-6c5da4cddba3]
# processed record [967] with id [d6659f66-188f-4864-85f1-b0b6206d919f]
# processed record [968] with id [11337b6c-2616-4445-a5b1-8ec7aa20df0e]
# processed record [969] with id [c6ea6421-7480-4476-9780-b71246ebbfd0]
# processed record [970] with id [eabbd7d6-6e4c-4d1b-b806-8b378639f3aa]
# processed record [971] with id [32d5b4b5-38e7-4339-a75e-dd577a7ab46d]
# processed record [972] with id [002ff3c1-9ed5-42fc-8079-7da1ea2e49bd]
# processed record [973] with id [85137e77-395e-44c5-98a9-7c6599067ef2]
# processed record [974] with id [3b29f53e-85fc-45d8-8159-62948a18e005]
# processed record [975] with id [737d0b1c-e864-4c3b-8cf6-6979d513bba7]
# processed record [976] with id [e29838d7-991d-4a61-9a88-6e9ff5262527]
# processed record [977] with id [a9eebe27-02d8-41f3-82d5-22bb99b4ff8f]
# processed record [978] with id [9c7ffe97-4a4e-40c2-af56-9b6444188e50]
# processed record [979] with id [75496721-2d53-4639-bd4a-c5df7a66c76b]
# processed record [980] with id [8f6b1949-99c9-4cc3-86c9-491c44e85e2a]
# processed record [981] with id [f61c8f6d-8905-441e-8325-a10f3e131d47]
# processed record [982] with id [ca7dd40f-b2a4-4d68-b2fd-ad4d283bf230]
# processed record [983] with id [b1386219-e93b-4d92-9cc4-bc18ce1051bf]
# processed record [984] with id [03ad544d-bcaa-4881-a25f-2e0023b4b728]
# processed record [985] with id [3869639e-0197-4012-8fab-6b1b3d5506ab]
# processed record [986] with id [1b7ad28f-9e46-42e0-861f-6de9a1761105]
# processed record [987] with id [ef7e84d7-88bb-44fb-981e-cb5036a50ba7]
# processed record [988] with id [a19db4f1-b6ad-4d57-bac7-05767ffb7d89]
# processed record [989] with id [5672f7e9-1f5a-4294-921d-35c10290a658]
# processed record [990] with id [f6fde7a7-9976-4bef-b5c9-651abbc3408e]
# processed record [991] with id [06de3d93-b734-4287-9ebf-65f5f110c2fe]
# processed record [992] with id [a27fb189-8868-46c3-b4cd-69eb587961ba]
# processed record [993] with id [4773c384-5051-4443-b5e9-36562dbe9dda]
# processed record [994] with id [c1efaf8e-c6a7-4322-83ae-5c21f165ec01]
# processed record [995] with id [41c69a5f-47b9-4933-ba9d-11b49dc630eb]
# processed record [996] with id [05749051-ba61-4884-be1d-0d44e3e068b5]
# processed record [997] with id [2f239fc6-11c9-4e7d-936e-71cf66fb0078]
# processed record [998] with id [8bd60a3b-f7ca-4222-bd1c-98057357d34d]
# processed record [999] with id [5b32e84b-7d24-4f2f-adb3-fae73c47241b]
# Processed 999 reviews and saved to ../data/transformed
# All reviews have been processed and saved as individual JSON files.
